# %%
import pandas as pd

# %%
hua = pd.read_excel(r"C:\Users\egonz\Dropbox\PC\Desktop\Data/HUANCAVELICA.xlsx")

# %%
hua["Region"] = "HUANCAVELICA"
region = hua["Region"]
hua.drop(labels = "Region", axis=1, inplace = True)
hua.insert(0, "Region", region)

# %%
hua.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
hua
# Out:
#            Region          District           Place 4_6_years_men  \
# 0    HUANCAVELICA               NaN             NaN           NaN
# 1    HUANCAVELICA               NaN  De 4 a 6 años            NaN
# 2    HUANCAVELICA               NaN              v.            M.
# 3    HUANCAVELICA  P. Huancavelica               71            39
# 4    HUANCAVELICA        Sacsamarca               3             3
# ..            ...               ...             ...           ...
# 114  HUANCAVELICA       Quirahccara               1             2
# 115  HUANCAVELICA            Ocoyyo               3             3
# 116  HUANCAVELICA          Ayamarca               4             2
# 117  HUANCAVELICA          Ocobamba              12            10
# 118  HUANCAVELICA             Total              68            54
#
#     4_6_years_women  4_6_years_total 6_14_years_men 6_14_years_women  \
# 0               NaN              NaN            NaN              NaN
# 1               NaN  De 6 a 14 años             NaN              NaN
# 2                T.               V.             M.               T.
# 3               110              304            336              640
# 4                 6               29              9               38
# ..              ...              ...            ...              ...
# 114               3               25             23               48
# 115               6               22             22               44
# 116               6               32             23               55
# 117              22               35             38               73
# 118             122              328            287              615
#
#     6_14_years_total man_read  ... not_finished_instr_women  \
# 0                NaN      NaN  ...                      NaN
# 1                NaN      NaN  ...                      NaN
# 2                 v.       M.  ...                       T.
# 3                149      139  ...                      607
# 4                  0        0  ...                       44
# ..               ...      ...  ...                      ...
# 114               19        6  ...                       51
# 115               12        2  ...                       49
# 116               12        1  ...                       61
# 117                4        1  ...                       95
# 118              139       58  ...                      734
#
#     not_finished_instr_total peruvian_men peruvian_women foreign_men  \
# 0                        NaN          NaN            NaN         NaN
# 1                  Peruanos           NaN    Extranjeros         NaN
# 2                         V.          M.              V.          M.
# 3                        375          375              0           0
# 4                         32           12              0           0
# ..                       ...          ...            ...         ...
# 114                       26           25              0           0
# 115                       25           25              0           0
# 116                       36           25              0           0
# 117                       47           48              0           0
# 118                      396          341              0           0
#
#     foreign_women    whites  natives mestizos blacks
# 0             NaN       NaN      NaN      NaN    NaN
# 1             NaN       NaN      NaN      NaN    NaN
# 2          Blanca  Indígena  Mestiza    Negra    NaN
# 3             288       384       78        0    NaN
# 4               0        44        0        0    NaN
# ..            ...       ...      ...      ...    ...
# 114             0        51        0        0    NaN
# 115             0        50        0        0    NaN
# 116             0        61        0        0    NaN
# 117             0        81       14        0    NaN
# 118             1       722       14        0    NaN
#
# [119 rows x 41 columns]

# %% [markdown]
# # Clean String Variables

# %%
# Translate to Uppercase variables 
hua["District"] =hua["District"].str.upper()
hua["Place"] = hua["Place"].str.upper()

# %%
hua["Place"] = hua["Place"].str.strip()
# Find errors with string = Total
errors =hua.loc[hua["Place"]=="TOTAL"]
error_list = errors.index.tolist()

hua_clean = hua.drop(hua.index[error_list])
hua_clean
# Out:
#            Region          District          Place 4_6_years_men  \
# 0    HUANCAVELICA               NaN            NaN           NaN
# 1    HUANCAVELICA               NaN  DE 4 A 6 AÑOS           NaN
# 2    HUANCAVELICA               NaN             V.            M.
# 3    HUANCAVELICA  P. HUANCAVELICA             NaN            39
# 4    HUANCAVELICA        SACSAMARCA            NaN             3
# ..            ...               ...            ...           ...
# 114  HUANCAVELICA       QUIRAHCCARA            NaN             2
# 115  HUANCAVELICA            OCOYYO            NaN             3
# 116  HUANCAVELICA          AYAMARCA            NaN             2
# 117  HUANCAVELICA          OCOBAMBA            NaN            10
# 118  HUANCAVELICA             TOTAL            NaN            54
#
#     4_6_years_women  4_6_years_total 6_14_years_men 6_14_years_women  \
# 0               NaN              NaN            NaN              NaN
# 1               NaN  De 6 a 14 años             NaN              NaN
# 2                T.               V.             M.               T.
# 3               110              304            336              640
# 4                 6               29              9               38
# ..              ...              ...            ...              ...
# 114               3               25             23               48
# 115               6               22             22               44
# 116               6               32             23               55
# 117              22               35             38               73
# 118             122              328            287              615
#
#     6_14_years_total man_read  ... not_finished_instr_women  \
# 0                NaN      NaN  ...                      NaN
# 1                NaN      NaN  ...                      NaN
# 2                 v.       M.  ...                       T.
# 3                149      139  ...                      607
# 4                  0        0  ...                       44
# ..               ...      ...  ...                      ...
# 114               19        6  ...                       51
# 115               12        2  ...                       49
# 116               12        1  ...                       61
# 117                4        1  ...                       95
# 118              139       58  ...                      734
#
#     not_finished_instr_total peruvian_men peruvian_women foreign_men  \
# 0                        NaN          NaN            NaN         NaN
# 1                  Peruanos           NaN    Extranjeros         NaN
# 2                         V.          M.              V.          M.
# 3                        375          375              0           0
# 4                         32           12              0           0
# ..                       ...          ...            ...         ...
# 114                       26           25              0           0
# 115                       25           25              0           0
# 116                       36           25              0           0
# 117                       47           48              0           0
# 118                      396          341              0           0
#
#     foreign_women    whites  natives mestizos blacks
# 0             NaN       NaN      NaN      NaN    NaN
# 1             NaN       NaN      NaN      NaN    NaN
# 2          Blanca  Indígena  Mestiza    Negra    NaN
# 3             288       384       78        0    NaN
# 4               0        44        0        0    NaN
# ..            ...       ...      ...      ...    ...
# 114             0        51        0        0    NaN
# 115             0        50        0        0    NaN
# 116             0        61        0        0    NaN
# 117             0        81       14        0    NaN
# 118             1       722       14        0    NaN
#
# [119 rows x 41 columns]

# %%
# Drop first 3 rows beacuse it does not serve us
hua_clean = hua_clean.drop([0, 1, 2],axis=0)
hua_clean
# Out:
#            Region          District Place 4_6_years_men 4_6_years_women  \
# 3    HUANCAVELICA  P. HUANCAVELICA    NaN            39             110
# 4    HUANCAVELICA        SACSAMARCA   NaN             3               6
# 5    HUANCAVELICA             TOTAL   NaN            42             116
# 6    HUANCAVELICA         P. ACORIA   NaN            12              30
# 7    HUANCAVELICA          AÑANCUSI   NaN            19              39
# ..            ...               ...   ...           ...             ...
# 114  HUANCAVELICA       QUIRAHCCARA   NaN             2               3
# 115  HUANCAVELICA            OCOYYO   NaN             3               6
# 116  HUANCAVELICA          AYAMARCA   NaN             2               6
# 117  HUANCAVELICA          OCOBAMBA   NaN            10              22
# 118  HUANCAVELICA             TOTAL   NaN            54             122
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               304            336              640              149      139
# 4                29              9               38                0        0
# 5               333            345              678              149      139
# 6                30             47              107               49       12
# 7                39             38              118               25        0
# ..              ...            ...              ...              ...      ...
# 114              25             23               48               19        6
# 115              22             22               44               12        2
# 116              32             23               55               12        1
# 117              35             38               73                4        1
# 118             328            287              615              139       58
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                      607                      375          375
# 4    ...                       44                       32           12
# 5    ...                      741                      407          387
# 6    ...                      137                       78           59
# 7    ...                      157                      100           57
# ..   ...                      ...                      ...          ...
# 114  ...                       51                       26           25
# 115  ...                       49                       25           25
# 116  ...                       61                       36           25
# 117  ...                       95                       47           48
# 118  ...                      734                      396          341
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3                0           0           288    384      78        0    NaN
# 4                0           0             0     44       0        0    NaN
# 5                0           0           288    428      78        0    NaN
# 6                0           0            31     80      26        0    NaN
# 7                0           0             4    152       1        0    NaN
# ..             ...         ...           ...    ...     ...      ...    ...
# 114              0           0             0     51       0        0    NaN
# 115              0           0             0     50       0        0    NaN
# 116              0           0             0     61       0        0    NaN
# 117              0           0             0     81      14        0    NaN
# 118              0           0             1    722      14        0    NaN
#
# [116 rows x 41 columns]

# %%
# drop by index
# Reset to index because we have removed rows and renumbering them
hua_clean = hua_clean.reset_index()
hua_clean
# Out:
#      index        Region          District Place 4_6_years_men  \
# 0        3  HUANCAVELICA  P. HUANCAVELICA    NaN            39
# 1        4  HUANCAVELICA        SACSAMARCA   NaN             3
# 2        5  HUANCAVELICA             TOTAL   NaN            42
# 3        6  HUANCAVELICA         P. ACORIA   NaN            12
# 4        7  HUANCAVELICA          AÑANCUSI   NaN            19
# ..     ...           ...               ...   ...           ...
# 111    114  HUANCAVELICA       QUIRAHCCARA   NaN             2
# 112    115  HUANCAVELICA            OCOYYO   NaN             3
# 113    116  HUANCAVELICA          AYAMARCA   NaN             2
# 114    117  HUANCAVELICA          OCOBAMBA   NaN            10
# 115    118  HUANCAVELICA             TOTAL   NaN            54
#
#     4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0               110             304            336              640
# 1                 6              29              9               38
# 2               116             333            345              678
# 3                30              30             47              107
# 4                39              39             38              118
# ..              ...             ...            ...              ...
# 111               3              25             23               48
# 112               6              22             22               44
# 113               6              32             23               55
# 114              22              35             38               73
# 115             122             328            287              615
#
#     6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0                149  ...                      607                      375
# 1                  0  ...                       44                       32
# 2                149  ...                      741                      407
# 3                 49  ...                      137                       78
# 4                 25  ...                      157                      100
# ..               ...  ...                      ...                      ...
# 111               19  ...                       51                       26
# 112               12  ...                       49                       25
# 113               12  ...                       61                       36
# 114                4  ...                       95                       47
# 115              139  ...                      734                      396
#
#     peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0            375              0           0           288    384      78
# 1             12              0           0             0     44       0
# 2            387              0           0           288    428      78
# 3             59              0           0            31     80      26
# 4             57              0           0             4    152       1
# ..           ...            ...         ...           ...    ...     ...
# 111           25              0           0             0     51       0
# 112           25              0           0             0     50       0
# 113           25              0           0             0     61       0
# 114           48              0           0             0     81      14
# 115          341              0           0             1    722      14
#
#     mestizos blacks
# 0          0    NaN
# 1          0    NaN
# 2          0    NaN
# 3          0    NaN
# 4          0    NaN
# ..       ...    ...
# 111        0    NaN
# 112        0    NaN
# 113        0    NaN
# 114        0    NaN
# 115        0    NaN
#
# [116 rows x 42 columns]

# %%
# indentify the types of Colum in the data 
a = hua_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
#As a precaution, we will check again that there are no rows with "Total"
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a1=a.dtypes

# %%
# This code will change the object column type to int64
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                       object
# District                     object
# Place                       float64
# 4_6_years_men                 int64
# 4_6_years_women               int64
# 4_6_years_total               int64
# 6_14_years_men                int64
# 6_14_years_women              int64
# 6_14_years_total              int64
# man_read                      int64
# women_read                    int64
# total_read                    int64
# men_not_read                  int64
# women_not_read                int64
# total_not_read                int64
# man_write                     int64
# women_write                   int64
# total_write                   int64
# men_not_write                 int64
# women_not_write               int64
# total_not_write               int64
# instruction_men               int64
# instruction_women             int64
# instruction_total             int64
# no_instruction_men            int64
# no_instruction_women          int64
# no_instruction_total          int64
# finished_instr_men            int64
# finished_instr_women          int64
# finished_instr_total          int64
# not_finished_instr_men        int64
# not_finished_instr_women      int64
# not_finished_instr_total      int64
# peruvian_men                  int64
# peruvian_women                int64
# foreign_men                   int64
# foreign_women                 int64
# whites                        int64
# natives                       int64
# mestizos                      int64
# blacks                       object
# dtype: object

# %%
a12['total_read'] = pd.to_numeric(a12['total_read'])
a12.dtypes

# %%
a12['total_write'] = pd.to_numeric(a12['total_write'])
a12.dtypes

# %%
a12["man_write"] = a12["man_write"].astype(int)

# %%
a12["total_write"] = pd.to_numeric(a12['total_write'])
a12.dtypes

# %%
a12

# %%
Code1= a12.to_excel("Region_Junin.xlsx")
Code1

# %%
df["edad_float"] = pd.to_numeric(df["A"], downcast="float")

# %%
a12= a.infer_objects()
a12.dtypes

# %%
txt = "    Total .      "

x = txt.strip(",.   ")

print(x)

# %%
txt = " Total ."

x = txt.strip(",.   ")

print(x)

# %%
txt = "        Total        ."

x = txt.strip()

print(x)

# %%
#Elimine los caracteres principales y finales:
#Elimina datos dentro del strip que no quieres q salgan
txt = ",,,,,rrttgg.....banana....rrr"

x = txt.strip(",.grt")

print(x)

# %%
txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")

# %%
junin = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/JUNIN_FINALIZADO.xlsx")
junin["Region"] = "JUNIN"
region = junin["Region"]
junin.drop(labels = "Region", axis=1, inplace = True)
junin.insert(0, "Region", region)
junin.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# Clean String Variables

# Translate to Uppercase variables 
junin["District"] =junin["District"].str.upper()
junin["Place"] = junin["Place"].str.upper()



junin["Place"] = junin["Place"].str.strip()
# Find errors with string = Total
errors =junin.loc[junin["Place"]=="TOTAL"]
error_list = errors.index.tolist()

junin_clean = junin.drop(junin.index[error_list])
junin_clean

# Drop first 3 rows beacuse it does not serve us
junin_clean = junin_clean.drop([0, 1, 2],axis=0)
junin_clean

# drop by index
# Reset to index because we have removed rows and renumbering them
junin_clean = junin_clean.reset_index()
junin_clean

# indentify the types of Colum in the data 
a = junin_clean.drop("index", axis=1)
a.dtypes

#As a precaution, we will check again that there are no rows with "Total"
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1

a1=a.dtypes

# This code will change the object column type to int64
a12= a.infer_objects()
a12.dtypes

a12

Code1= a12.to_excel("Region_Junin.xlsx")
Code1

df["edad_float"] = pd.to_numeric(df["A"], downcast="float")


a12= a.infer_objects()
a12.dtypes



txt = "    Total .      "

x = txt.strip(",.   ")

print(x)

txt = " Total ."

x = txt.strip(",.   ")

print(x)

txt = "        Total        ."

x = txt.strip()

print(x)

#Elimine los caracteres principales y finales:
#Elimina datos dentro del strip que no quieres q salgan
txt = ",,,,,rrttgg.....banana....rrr"

x = txt.strip(",.grt")

print(x)

txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")
