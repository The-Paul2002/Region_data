# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
amazonas = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/AMAZONAS_FINALIZADO.xlsx")
amazonas["Region"] = "AMAZONAS"
region = amazonas["Region"]
amazonas.drop(labels = "Region", axis=1, inplace = True)
amazonas.insert(0, "Region", region)
amazonas.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
amazonas
# Out:
#        Region     District           Place   4_6_years_men 4_6_years_women  \
# 0    AMAZONAS          NaN             NaN             NaN             NaN
# 1    AMAZONAS          NaN             NaN  De 4 a 6 años              NaN
# 2    AMAZONAS          NaN             NaN              v.              M.
# 3    AMAZONAS  Chachapoyas  H. Quipachacha               5               6
# 4    AMAZONAS  Chachapoyas  p. Chachapoyas              75              64
# ..        ...          ...             ...             ...             ...
# 99   AMAZONAS  Baguaichico          Total               10               6
# 100  AMAZONAS     Tumbilla      P.Tumbilla               4               6
# 101  AMAZONAS     Tumbilla         H.Recta               6               2
# 102  AMAZONAS     Tumbilla       C.Carosha               2               0
# 103  AMAZONAS     Tumbilla          Total               12               8
#
# ...

# %%
amazonas["District"] = amazonas["District"].str.upper()
amazonas["Place"] = amazonas["Place"].str.upper()

# %%
amazonas["Place"] = amazonas["Place"].str.strip()

# %%
errors = amazonas.loc[amazonas["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
amazonas_clean = amazonas.drop(amazonas.index[errors_list])
amazonas_clean
# Out:
#        Region     District           Place   4_6_years_men 4_6_years_women  \
# 0    AMAZONAS          NaN             NaN             NaN             NaN
# 1    AMAZONAS          NaN             NaN  De 4 a 6 años              NaN
# 2    AMAZONAS          NaN             NaN              v.              M.
# 3    AMAZONAS  CHACHAPOYAS  H. QUIPACHACHA               5               6
# 4    AMAZONAS  CHACHAPOYAS  P. CHACHAPOYAS              75              64
# ..        ...          ...             ...             ...             ...
# 97   AMAZONAS  BAGUAICHICO   P.BAGUAICHICO               5               6
# 98   AMAZONAS  BAGUAICHICO             PEA               5               0
# 100  AMAZONAS     TUMBILLA      P.TUMBILLA               4               6
# 101  AMAZONAS     TUMBILLA         H.RECTA               6               2
# 102  AMAZONAS     TUMBILLA       C.CAROSHA               2               0
#
# ...

# %%
amazonas_clean = amazonas_clean.drop([0, 1, 2],axis=0)
amazonas_clean
# Out:
#        Region     District           Place 4_6_years_men 4_6_years_women  \
# 3    AMAZONAS  CHACHAPOYAS  H. QUIPACHACHA             5               6
# 4    AMAZONAS  CHACHAPOYAS  P. CHACHAPOYAS            75              64
# 5    AMAZONAS  CHACHAPOYAS          TAQUIA            14               5
# 6    AMAZONAS  CHACHAPOYAS         HIDALGO             0               0
# 7    AMAZONAS  CHACHAPOYAS     ROJAS CUCHO             0               2
# ..        ...          ...             ...           ...             ...
# 97   AMAZONAS  BAGUAICHICO   P.BAGUAICHICO             5               6
# 98   AMAZONAS  BAGUAICHICO             PEA             5               0
# 100  AMAZONAS     TUMBILLA      P.TUMBILLA             4               6
# 101  AMAZONAS     TUMBILLA         H.RECTA             6               2
# 102  AMAZONAS     TUMBILLA       C.CAROSHA             2               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# ...

# %%
amazonas_clean = amazonas_clean.reset_index()
amazonas_clean
# Out:
#     index    Region     District           Place 4_6_years_men  \
# 0       3  AMAZONAS  CHACHAPOYAS  H. QUIPACHACHA             5
# 1       4  AMAZONAS  CHACHAPOYAS  P. CHACHAPOYAS            75
# 2       5  AMAZONAS  CHACHAPOYAS          TAQUIA            14
# 3       6  AMAZONAS  CHACHAPOYAS         HIDALGO             0
# 4       7  AMAZONAS  CHACHAPOYAS     ROJAS CUCHO             0
# ..    ...       ...          ...             ...           ...
# 63     97  AMAZONAS  BAGUAICHICO   P.BAGUAICHICO             5
# 64     98  AMAZONAS  BAGUAICHICO             PEA             5
# 65    100  AMAZONAS     TUMBILLA      P.TUMBILLA             4
# 66    101  AMAZONAS     TUMBILLA         H.RECTA             6
# 67    102  AMAZONAS     TUMBILLA       C.CAROSHA             2
#
#    4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0                6              11             20               19
# 1               64             139            380              353
# ...

# %%
a =amazonas_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
Code1= a12.to_excel("Region_Amazonas.xlsx")
Code1

# %%
# Drop first 3 rows .....
#amazonas = amazonas.drop([0, 1, 2],axis=0)
#amazonas

# %%
# Translate to Uppercase variables 
amazonas["District"] = amazonas["District"].str.upper()
amazonas["Place"] = amazonas["Place"].str.upper()

# %%
amazonas["Place"] = amazonas["Place"].str.strip()
errors = amazonas.loc[amazonas["Place"]=="TOTAL"]
errors_list = errors.index.tolist()
#amazonas["Place"] = re.sub(' +', ' ', amazonas["Place
#import re
#re.sub(' +', ' ',"Paul Melo  Ramos" )

# %%
# Reset Index
amazonas = amazonas.reset_index()
amazonas

# %%
# Find errors with string = Total
errors = amazonas.loc[amazonas["Place"]=="TOTAL"]
error_list = errors.index.tolist()

# %% [markdown]
# # Drop observations ....

# %%
# drop by index
amazonas_clean = amazonas.drop(amazonas.index[errors_list])
amazonas_clean

# %%
amazonas_clean = amazonas_clean.drop([0, 1, 2],axis=0)
amazonas_clean

# %%
amazonas_clean.drop("index", axis=1)

# %%
amazonas_clean.dtypes

# %%
B1=Amazonas.drop(Amazonas.index[[ 10, 13, 15, 17, 21, 24, 28, 33, 39, 41, 43, 46, 48, 52, 54, 56, 59,
            61, 63, 65, 67, 69, 71, 73, 75, 77, 80]])
B01 = B1.drop([0, 1, 2],axis=0)

# %%
drop = amazonas.index[[ 10, 13, 15, 17, 21, 24, 28, 33, 39, 41, 43, 46, 48, 52, 54, 56, 59,
            61, 63, 65, 67, 69, 71, 73, 75, 77, 80]]

# %%
type(drop)

# %%
Code1= B01.to_excel("Amazonas_finalizado.xlsx")
Code1
