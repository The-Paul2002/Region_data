# %%
import pandas as pd

# %%
ICA = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/ICA_FINALIZADO.xlsx")
ICA["Region"] = "ICA"
Region = ICA["Region"]
ICA.drop(labels = "Region", axis=1, inplace = True)
ICA.insert(0, "Region", Region)
ICA.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
ICA["District"] =ICA["District"].str.upper()
ICA["Place"] = ICA["Place"].str.upper()

# %%
ICA["Place"] = ICA["Place"].str.strip()
# Find errors with string = Total
errors = ICA.loc[ICA["Place"]=="TOTAL"]
error_list = errors.index.tolist()

# %%
ICA_clean = ICA.drop(ICA.index[error_list])

# %%
ICA_clean = ICA_clean.drop([0, 1, 2],axis=0)

# %%
ICA_clean = ICA_clean.reset_index()
ICA_clean
# Out:
#     index Region            District                      Place 4_6_years_men  \
# 0       3    ICA                 ICA                     CD.ICA            83
# 1       4    ICA                 ICA                P.COMATRANA             7
# 2       5    ICA                 ICA                   CACHICHE             4
# 3       6    ICA                 ICA  SAN JOAQUIN (CHANCHAJAYA)             8
# 4       7    ICA                 ICA                   TINGUIÑA            10
# 5       8    ICA                 ICA                    PARCONA            14
# 6       9    ICA                 ICA                     ORONGO            22
# 7      10    ICA                 ICA                     SARAJA            10
# 8      12    ICA  SAN JUAN BAUSTISTA        P.SAN JUAN BAUTISTA             2
# 9      13    ICA  SAN JUAN BAUSTISTA                A.GUADALUPE             3
# 10     14    ICA  SAN JUAN BAUSTISTA                   COLLASOH             0
# 11     15    ICA  SAN JUAN BAUSTISTA                CARMEN ALTO             7
# 12     16    ICA  SAN JUAN BAUSTISTA          C.CAMINO DE REYES             0
# 13     17    ICA  SAN JUAN BAUSTISTA                      OLIVO             7
# 14     18    ICA  SAN JUAN BAUSTISTA              H.SULTANJALLA             2
# 15     20    ICA        PUEBLO NUEVO             P.PUEBLO NUEVO             7
# 16     21    ICA        PUEBLO NUEVO                A.TALLAMANA            25
# 17     23    ICA               NAZCA                    V.NAZCA             3
# 18     25    ICA               PISCO                    P.PISCO           121
# 19     26    ICA               PISCO                  H.CAUCATO             1
# 20     27    ICA               PISCO               C.SAN MIGUEL             9
# 21     28    ICA               PISCO           PLAYA DEL PUERTO            23
# 22     29    ICA               PISCO               C.SAN ANDRÉS            13
# 23     31    ICA               HUMAY                    P.HUMAY             4
# 24     32    ICA               HUMAY                 CHUNCHANGA            12
# 25     34    ICA            HUÁNCANO                 P.HUÁNCANO             7
# 26     36    ICA        CHINCHA ALTA             P.CHINCHA ALTA           103
# 27     37    ICA        CHINCHA ALTA                  ÑOCO BAJO             5
# 28     38    ICA        CHINCHA ALTA                 CONDORILLO            45
# 29     39    ICA        CHINCHA ALTA                  ÑOCO ALTO             2
# 30     40    ICA        CHINCHA ALTA                      PILPA             0
# 31     41    ICA        CHINCHA ALTA             ACEQUIA GRANDE            27
# 32     42    ICA        CHINCHA ALTA                  C.SUNAMPE            20
# 33     44    ICA        CHINCHA BAJA             P.CHINCHA BAJA            42
# 34     45    ICA        CHINCHA BAJA             H.HOJA REDONDA             2
# 35     47    ICA       TAMBO DE MORA            P.TAMBO DE MORA            15
#
#    4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0              107             190            538              569
# 1                7              14             32               24
# 2                8              12             25               16
# 3                7              15             56               23
# 4               12              22             65               48
# 5                5              19             37               26
# 6               13              35             84               62
# 7               13              23             44               38
# 8                3               5             33               40
# 9                5               8             63               64
# 10               0               0             25               25
# 11               9              16             57               42
# 12               1               1             44               30
# 13               2               9             13                9
# 14               2               4             48               28
# 15               5              12             82               41
# 16               5              30             60               38
# 17               1               4             36               39
# 18             115             236            359              431
# 19               0               1             29               12
# 20              15              24             79               67
# 21              25              48            105              115
# 22              15              28             53               54
# 23               8              12             56               38
# 24              13              25             50               30
# 25               4              11             35               27
# 26             115             218            478              496
# 27               3               8            170              160
# 28              45              90            170              155
# 29               0               2            158              104
# 30               0               0            214                0
# 31              28              55            119               92
# 32              35              55            135              106
# 33              59             101            319              344
# 34               0               2             23                0
# 35              18              33            104              106
#
#    6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0              1107  ...                      649                     1221
# 1                56  ...                       31                       70
# 2                41  ...                       24                       53
# 3                79  ...                       30                       94
# 4               113  ...                       58                      133
# 5                63  ...                       31                       81
# 6               146  ...                       74                      179
# 7                82  ...                       51                      105
# 8                73  ...                       43                       76
# 9               127  ...                       69                      135
# 10               50  ...                       25                       50
# 11               99  ...                       51                      115
# 12               74  ...                       31                       75
# 13               22  ...                       11                       31
# 14               76  ...                       30                       80
# 15              123  ...                       46                      135
# 16               98  ...                       43                      128
# 17               75  ...                       35                       66
# 18              790  ...                      481                      914
# 19               41  ...                       12                       42
# 20              146  ...                       82                      170
# 21              220  ...                      132                      255
# 22              107  ...                       69                      133
# 23               94  ...                       46                      103
# 24               80  ...                       43                      105
# 25               62  ...                       31                       66
# 26              974  ...                      507                      955
# 27              330  ...                      155                      315
# 28              325  ...                      200                      411
# 29              262  ...                      104                      262
# 30              214  ...                        0                      192
# 31              211  ...                      116                      251
# 32              241  ...                      133                      262
# 33              663  ...                      394                      742
# 34               23  ...                        0                       25
# 35              210  ...                      121                      236
#
#    peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0           621            676           0             0    289     617
# 1            39             31           0             0      0      70
# 2            29             24           0             0      1      52
# 3            64             30           0             0      0      39
# 4            75             60           0             0      0      72
# 5            51             31           0             0      0      80
# 6           106             75           0             0      4      90
# 7            54             51           0             0      0      61
# 8            35             43           0             0     10      51
# 9            66             69           0             0      9     120
# 10           25             25           0             0      0      50
# 11           64             51           0             0      0      63
# 12           44             31           0             0      7      62
# 13           20             11           0             0      0      12
# 14           50             30           0             0      3      61
# 15           89             46           0             0      0     134
# 16           85             43           0             0     11     117
# 17           39             40           0             0     14       3
# 18          480            546           0             0    152     292
# 19           30             12           0             0      0      27
# 20           88             82           0             0      0      80
# 21          128            140           0             0     57      92
# 22           66             69           0             0      5     128
# 23           60             46           0             0     18      58
# 24           62             43           0             0      3      70
# 25           42             31           0             0     19      34
# 26          551            611           0             0    224     603
# 27          175            163           0             0      0     338
# 28          215            200           0             0      0     409
# 29          160            104           0             0      3     259
# 30          214              0           0             0      1     213
# 31          264              0           0             0      0     264
# 32          155            141           0             0      1     268
# 33          361            403           0             0     52     394
# 34           25              0           0             0      0      20
# 35          119            124           0             0     49      21
#
#    mestizos blacks
# 0       357     34
# 1         0      0
# 2         0      0
# 3        55      0
# 4        32      1
# 5         0      2
# 6        87      0
# 7        37      7
# 8         0     17
# 9         6      0
# 10        0      0
# 11       47      5
# 12        6      0
# 13       18      1
# 14       12      4
# 15        0      1
# 16        0      0
# 17       60      2
# 18       25    547
# 19        0     15
# 20       63     27
# 21       91     28
# 22        0      2
# 23       25      5
# 24       20     12
# 25       19      1
# 26      261    104
# 27        0      0
# 28        0      6
# 29        0      2
# 30        0      0
# 31        0      0
# 32       23      4
# 33      201    117
# 34        5      0
# 35      127     46
#
# [36 rows x 42 columns]

# %%
a = ICA_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object

# %%
errors1 =a12.loc[a12["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
Code1= a12.to_excel("Region_Ica.xlsx")
Code1
