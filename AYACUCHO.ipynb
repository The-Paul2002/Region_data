# %%
 import pandas as pd

# %% [markdown]
# # Import data

# %%
ay = pd.read_excel(r"C:\Users\egonz\Dropbox\PC\Desktop\Data/AYACUCHO.xlsx")
ay["Region"] = "AYACUCHO"
region = ay["Region"]
#ay.drop(labels = "Region", axis=1, inplace = True)
#ay.insert(0, "Region", region)

# %%
region = ay["Region"]
ay.drop(labels = "Region", axis=1, inplace = True)
ay.insert(0, "Region", region)

# %%
ay.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
ay
# Out:
#         Region            District           Place 4_6_years_men  \
# 0          NaN                 NaN             NaN           NaN
# 1          NaN                 NaN  De 4 a 6 años            NaN
# 2          NaN                 NaN              v.            M.
# 3     Ayacucho          P.Ayacucho             189           166
# 4     Ayacucho  Parroquia de Santa              52            24
# ..         ...                 ...             ...           ...
# 171    Canaria               Total               0             0
# 172  Vischongo         P.Vischongo               0             0
# 173  Vischongo               Total               0             0
# 174      Paras            P.´Paras               0             0
# 175      Paras               Total               0             0
#
#     4_6_years_women  4_6_years_total 6_14_years_men 6_14_years_women  \
# 0               NaN              NaN            NaN              NaN
# 1               NaN  De 6 a 14 años             NaN              NaN
# 2                T.               V.             M.               T.
# 3               355              676            665             1341
# 4                76              173            138              311
# ..              ...              ...            ...              ...
# 171               0                0              0                0
# 172               0               15              0               15
# 173               0                0              0                0
# 174               0               15              0               15
# 175               0                0              0                0
#
#     6_14_years_total man_read  ... not_finished_instr_women  \
# 0                NaN      NaN  ...                      NaN
# 1                NaN      NaN  ...                      NaN
# 2                 v.       M.  ...                       T.
# 3                360      257  ...                     1594
# 4                 40       15  ...                      381
# ..               ...      ...  ...                      ...
# 171                0        0  ...                        0
# 172                3        0  ...                       15
# 173                0        0  ...                        0
# 174               15        0  ...                       14
# 175                0        0  ...                        0
#
#     not_finished_instr_total peruvian_men peruvian_women foreign_men  \
# 0                        NaN          NaN            NaN         NaN
# 1                  Peruanos           NaN    Extranjeros         NaN
# 2                         V.          M.              V.          M.
# 3                        865          831              0           0
# 4                        225          162              0           0
# ..                       ...          ...            ...         ...
# 171                        0            0              0           0
# 172                       15            0              0           0
# 173                        0            0              0           0
# 174                       15            0              0           0
# 175                        0            0              0           0
#
#     foreign_women    whites  natives mestizos    blacks
# 0             NaN       NaN      NaN      NaN  AYACUCHO
# 1             NaN       NaN      NaN      NaN  AYACUCHO
# 2          Blanca  Indígena  Mestiza    Negra  AYACUCHO
# 3             471      1085      139        1  AYACUCHO
# 4              31       348        8        0  AYACUCHO
# ..            ...       ...      ...      ...       ...
# 171             0         0        0        0  AYACUCHO
# 172             0        15        0        0  AYACUCHO
# 173             0         0        0        0  AYACUCHO
# 174             7         4        4        0  AYACUCHO
# 175             0         0        0        0  AYACUCHO
#
# [176 rows x 41 columns]

# %% [markdown]
# # Clean String Variables

# %%
# Translate to Uppercase variables 
ay["District"] =ay["District"].str.upper()
ay["Place"] = ay["Place"].str.upper()

# %%
ay["Place"] = ay["Place"].str.strip()
# Find errors with string = Total
errors =ay.loc[ay["Place"]=="TOTAL"]
error_list = errors.index.tolist()

ay_clean = ay.drop(ay.index[error_list])
ay_clean
# Out:
#         Region            District          Place 4_6_years_men  \
# 0          NaN                 NaN            NaN           NaN
# 1          NaN                 NaN  DE 4 A 6 AÑOS           NaN
# 2          NaN                 NaN             V.            M.
# 3     Ayacucho          P.AYACUCHO            NaN           166
# 4     Ayacucho  PARROQUIA DE SANTA            NaN            24
# ..         ...                 ...            ...           ...
# 171    Canaria               TOTAL            NaN             0
# 172  Vischongo         P.VISCHONGO            NaN             0
# 173  Vischongo               TOTAL            NaN             0
# 174      Paras            P.´PARAS            NaN             0
# 175      Paras               TOTAL            NaN             0
#
#     4_6_years_women  4_6_years_total 6_14_years_men 6_14_years_women  \
# 0               NaN              NaN            NaN              NaN
# 1               NaN  De 6 a 14 años             NaN              NaN
# 2                T.               V.             M.               T.
# 3               355              676            665             1341
# 4                76              173            138              311
# ..              ...              ...            ...              ...
# 171               0                0              0                0
# 172               0               15              0               15
# 173               0                0              0                0
# 174               0               15              0               15
# 175               0                0              0                0
#
#     6_14_years_total man_read  ... not_finished_instr_women  \
# 0                NaN      NaN  ...                      NaN
# 1                NaN      NaN  ...                      NaN
# 2                 v.       M.  ...                       T.
# 3                360      257  ...                     1594
# 4                 40       15  ...                      381
# ..               ...      ...  ...                      ...
# 171                0        0  ...                        0
# 172                3        0  ...                       15
# 173                0        0  ...                        0
# 174               15        0  ...                       14
# 175                0        0  ...                        0
#
#     not_finished_instr_total peruvian_men peruvian_women foreign_men  \
# 0                        NaN          NaN            NaN         NaN
# 1                  Peruanos           NaN    Extranjeros         NaN
# 2                         V.          M.              V.          M.
# 3                        865          831              0           0
# 4                        225          162              0           0
# ..                       ...          ...            ...         ...
# 171                        0            0              0           0
# 172                       15            0              0           0
# 173                        0            0              0           0
# 174                       15            0              0           0
# 175                        0            0              0           0
#
#     foreign_women    whites  natives mestizos    blacks
# 0             NaN       NaN      NaN      NaN  AYACUCHO
# 1             NaN       NaN      NaN      NaN  AYACUCHO
# 2          Blanca  Indígena  Mestiza    Negra  AYACUCHO
# 3             471      1085      139        1  AYACUCHO
# 4              31       348        8        0  AYACUCHO
# ..            ...       ...      ...      ...       ...
# 171             0         0        0        0  AYACUCHO
# 172             0        15        0        0  AYACUCHO
# 173             0         0        0        0  AYACUCHO
# 174             7         4        4        0  AYACUCHO
# 175             0         0        0        0  AYACUCHO
#
# [176 rows x 41 columns]

# %%
# Drop first 3 rows beacuse it does not serve us
ay_clean = ay_clean.drop([0, 1, 2],axis=0)
ay_clean
# Out:
#         Region            District Place 4_6_years_men 4_6_years_women  \
# 3     Ayacucho          P.AYACUCHO   NaN           166             355
# 4     Ayacucho  PARROQUIA DE SANTA   NaN            24              76
# 5     Ayacucho       B.CARMEN ALTO   NaN             5              10
# 6     Ayacucho   SAN JUAN BAUTISTA   NaN             8              16
# 7     Ayacucho               TOTAL   NaN             0               0
# ..         ...                 ...   ...           ...             ...
# 171    Canaria               TOTAL   NaN             0               0
# 172  Vischongo         P.VISCHONGO   NaN             0               0
# 173  Vischongo               TOTAL   NaN             0               0
# 174      Paras            P.´PARAS   NaN             0               0
# 175      Paras               TOTAL   NaN             0               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               676            665             1341              360      257
# 4               173            138              311               40       15
# 5                20             20               40                9        2
# 6                17             17               34                4        0
# 7                 0              0                0                0        0
# ..              ...            ...              ...              ...      ...
# 171               0              0                0                0        0
# 172              15              0               15                3        0
# 173               0              0                0                0        0
# 174              15              0               15               15        0
# 175               0              0                0                0        0
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                     1594                      865          831
# 4    ...                      381                      225          162
# 5    ...                       50                       25           25
# 6    ...                       50                       25           25
# 7    ...                        0                        0            0
# ..   ...                      ...                      ...          ...
# 171  ...                        0                        0            0
# 172  ...                       15                       15            0
# 173  ...                        0                        0            0
# 174  ...                       14                       15            0
# 175  ...                        0                        0            0
#
#     peruvian_women foreign_men foreign_women whites natives mestizos    blacks
# 3                0           0           471   1085     139        1  AYACUCHO
# 4                0           0            31    348       8        0  AYACUCHO
# 5                0           0             3     47       0        0  AYACUCHO
# 6                0           0             0     50       0        0  AYACUCHO
# 7                0           0             0      0       0        0  AYACUCHO
# ..             ...         ...           ...    ...     ...      ...       ...
# 171              0           0             0      0       0        0  AYACUCHO
# 172              0           0             0     15       0        0  AYACUCHO
# 173              0           0             0      0       0        0  AYACUCHO
# 174              0           0             7      4       4        0  AYACUCHO
# 175              0           0             0      0       0        0  AYACUCHO
#
# [173 rows x 41 columns]

# %%
# drop by index
# Reset to index because we have removed rows and renumbering them
ay_clean = ay_clean.reset_index()
ay_clean
# Out:
#      index     Region            District Place 4_6_years_men 4_6_years_women  \
# 0        3   Ayacucho          P.AYACUCHO   NaN           166             355
# 1        4   Ayacucho  PARROQUIA DE SANTA   NaN            24              76
# 2        5   Ayacucho       B.CARMEN ALTO   NaN             5              10
# 3        6   Ayacucho   SAN JUAN BAUTISTA   NaN             8              16
# 4        7   Ayacucho               TOTAL   NaN             0               0
# ..     ...        ...                 ...   ...           ...             ...
# 168    171    Canaria               TOTAL   NaN             0               0
# 169    172  Vischongo         P.VISCHONGO   NaN             0               0
# 170    173  Vischongo               TOTAL   NaN             0               0
# 171    174      Paras            P.´PARAS   NaN             0               0
# 172    175      Paras               TOTAL   NaN             0               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# 0               676            665             1341              360  ...
# 1               173            138              311               40  ...
# 2                20             20               40                9  ...
# 3                17             17               34                4  ...
# 4                 0              0                0                0  ...
# ..              ...            ...              ...              ...  ...
# 168               0              0                0                0  ...
# 169              15              0               15                3  ...
# 170               0              0                0                0  ...
# 171              15              0               15               15  ...
# 172               0              0                0                0  ...
#
#     not_finished_instr_women not_finished_instr_total peruvian_men  \
# 0                       1594                      865          831
# 1                        381                      225          162
# 2                         50                       25           25
# 3                         50                       25           25
# 4                          0                        0            0
# ..                       ...                      ...          ...
# 168                        0                        0            0
# 169                       15                       15            0
# 170                        0                        0            0
# 171                       14                       15            0
# 172                        0                        0            0
#
#     peruvian_women foreign_men foreign_women whites natives mestizos    blacks
# 0                0           0           471   1085     139        1  AYACUCHO
# 1                0           0            31    348       8        0  AYACUCHO
# 2                0           0             3     47       0        0  AYACUCHO
# 3                0           0             0     50       0        0  AYACUCHO
# 4                0           0             0      0       0        0  AYACUCHO
# ..             ...         ...           ...    ...     ...      ...       ...
# 168              0           0             0      0       0        0  AYACUCHO
# 169              0           0             0     15       0        0  AYACUCHO
# 170              0           0             0      0       0        0  AYACUCHO
# 171              0           0             7      4       4        0  AYACUCHO
# 172              0           0             0      0       0        0  AYACUCHO
#
# [173 rows x 42 columns]

# %%
# indentify the types of Colum in the data 
a = ay_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
#As a precaution, we will check again that there are no rows with "Total"
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a1=a.dtypes

# %% [markdown]
# ## OBSERVACIÓN PLACE IS FLOAT "CASO  RARO"

# %%
# This code will change the object column type to int64
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                       object
# District                     object
# Place                       float64
# 4_6_years_men                 int64
# 4_6_years_women               int64
# 4_6_years_total               int64
# 6_14_years_men                int64
# 6_14_years_women              int64
# 6_14_years_total              int64
# man_read                      int64
# women_read                    int64
# total_read                    int64
# men_not_read                  int64
# women_not_read                int64
# total_not_read                int64
# man_write                     int64
# women_write                   int64
# total_write                   int64
# men_not_write                 int64
# women_not_write               int64
# total_not_write               int64
# instruction_men               int64
# instruction_women             int64
# instruction_total             int64
# no_instruction_men            int64
# no_instruction_women          int64
# no_instruction_total          int64
# finished_instr_men            int64
# finished_instr_women          int64
# finished_instr_total          int64
# not_finished_instr_men        int64
# not_finished_instr_women      int64
# not_finished_instr_total      int64
# peruvian_men                  int64
# peruvian_women                int64
# foreign_men                   int64
# foreign_women                 int64
# whites                        int64
# natives                       int64
# mestizos                      int64
# blacks                       object
# dtype: object

# %%
Code1= a12.to_excel("Region_Ayacucho.xlsx")
Code1
