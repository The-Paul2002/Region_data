# %%
import pandas as pd

# %%
H = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/HUÁNUCO_FINALIZADO.xlsx")
H["Region"] = "HUÁNUCO"
Region = H["Region"]
H.drop(labels = "Region", axis=1, inplace = True)
H.insert(0, "Region", Region)
H.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
H["District"] =H["District"].str.upper()
H["Place"] = H["Place"].str.upper()

# %%
H["Place"] = H["Place"].str.strip()
# Find errors with string = Total
errors =H.loc[H["Place"]=="TOTAL"]
error_list = errors.index.tolist()

H_clean = H.drop(H.index[error_list])
H_clean
# Out:
#       Region District          Place   4_6_years_men 4_6_years_women  \
# 0    HUÁNUCO      NaN            NaN             NaN             NaN
# 1    HUÁNUCO      NaN            NaN  De 4 a 6 años              NaN
# 2    HUÁNUCO      NaN            NaN              v.              M.
# 3    HUÁNUCO  HUÁNUCO     P. HUÁNUCO             105             114
# 4    HUÁNUCO  HUÁNUCO         CAYRAN               4               2
# ..       ...      ...            ...             ...             ...
# 133  HUÁNUCO  ARANCAY   P.DE ARANCAY               0               6
# 134  HUÁNUCO  ARANCAY   A.DE HUAMPOY               5               2
# 135  HUÁNUCO  ARANCAY  C.SAN ANTONIO               1               1
# 136  HUÁNUCO  ARANCAY       HUARMACA               6               3
# 137  HUÁNUCO  ARANCAY      SAN PEDRO               0               0
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               219              525              466              991
# 4                 6               18               18               36
# ..              ...              ...              ...              ...
# 133               6               25               19               44
# 134               7               20               23               43
# 135               2               23               11               34
# 136               9               19                3               22
# 137               0               22                7               29
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3        292  ...                      554                     1156
# 4          0  ...                       20                       42
# ..       ...  ...                      ...                      ...
# 133       22  ...                       25                       49
# 134        5  ...                       25                       50
# 135        0  ...                       12                       36
# 136        2  ...                        6                       31
# 137        1  ...                        7                       29
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3            630            580            0             0     399       202
# 4             22             20            0             0       0        40
# ..           ...            ...          ...           ...     ...       ...
# 133           25             25            0             0       0         6
# 134           25             25            0             0       0        34
# 135           24             12            0             0       0        30
# 136           25              6            0             0       0        18
# 137           22              7            0             0       0        25
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3        609      0
# 4          2      0
# ..       ...    ...
# 133       44      0
# 134       16      0
# 135        6      0
# 136       13      0
# 137        4      0
#
# [117 rows x 41 columns]

# %%
H_clean = H_clean.drop([0, 1, 2],axis=0)
H_clean
# Out:
#       Region District          Place 4_6_years_men 4_6_years_women  \
# 3    HUÁNUCO  HUÁNUCO     P. HUÁNUCO           105             114
# 4    HUÁNUCO  HUÁNUCO         CAYRAN             4               2
# 5    HUÁNUCO  HUÁNUCO     C. QUIRCAN             3               3
# 6    HUÁNUCO  HUÁNUCO         PAUCAR            13              14
# 7    HUÁNUCO  HUÁNUCO      MATAMARCA             3               5
# ..       ...      ...            ...           ...             ...
# 133  HUÁNUCO  ARANCAY   P.DE ARANCAY             0               6
# 134  HUÁNUCO  ARANCAY   A.DE HUAMPOY             5               2
# 135  HUÁNUCO  ARANCAY  C.SAN ANTONIO             1               1
# 136  HUÁNUCO  ARANCAY       HUARMACA             6               3
# 137  HUÁNUCO  ARANCAY      SAN PEDRO             0               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               219            525              466              991      292
# 4                 6             18               18               36        0
# 5                 6             18                5               23        0
# 6                27             62               45              107        3
# 7                 8             22               10               32        0
# ..              ...            ...              ...              ...      ...
# 133               6             25               19               44       22
# 134               7             20               23               43        5
# 135               2             23               11               34        0
# 136               9             19                3               22        2
# 137               0             22                7               29        1
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                      554                     1156          630
# 4    ...                       20                       42           22
# 5    ...                        8                       29           21
# 6    ...                       59                      134           75
# 7    ...                       15                       40           25
# ..   ...                      ...                      ...          ...
# 133  ...                       25                       49           25
# 134  ...                       25                       50           25
# 135  ...                       12                       36           24
# 136  ...                        6                       31           25
# 137  ...                        7                       29           22
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3              580           0             0    399     202      609      0
# 4               20           0             0      0      40        2      0
# 5                8           0             0      0      29        0      0
# 6               59           0             0      0     134        0      0
# 7               15           0             0      0      27       13      0
# ..             ...         ...           ...    ...     ...      ...    ...
# 133             25           0             0      0       6       44      0
# 134             25           0             0      0      34       16      0
# 135             12           0             0      0      30        6      0
# 136              6           0             0      0      18       13      0
# 137              7           0             0      0      25        4      0
#
# [114 rows x 41 columns]

# %%
H_clean = H_clean.reset_index()
H_clean
# Out:
#      index   Region District          Place 4_6_years_men 4_6_years_women  \
# 0        3  HUÁNUCO  HUÁNUCO     P. HUÁNUCO           105             114
# 1        4  HUÁNUCO  HUÁNUCO         CAYRAN             4               2
# 2        5  HUÁNUCO  HUÁNUCO     C. QUIRCAN             3               3
# 3        6  HUÁNUCO  HUÁNUCO         PAUCAR            13              14
# 4        7  HUÁNUCO  HUÁNUCO      MATAMARCA             3               5
# ..     ...      ...      ...            ...           ...             ...
# 109    133  HUÁNUCO  ARANCAY   P.DE ARANCAY             0               6
# 110    134  HUÁNUCO  ARANCAY   A.DE HUAMPOY             5               2
# 111    135  HUÁNUCO  ARANCAY  C.SAN ANTONIO             1               1
# 112    136  HUÁNUCO  ARANCAY       HUARMACA             6               3
# 113    137  HUÁNUCO  ARANCAY      SAN PEDRO             0               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# 0               219            525              466              991  ...
# 1                 6             18               18               36  ...
# 2                 6             18                5               23  ...
# 3                27             62               45              107  ...
# 4                 8             22               10               32  ...
# ..              ...            ...              ...              ...  ...
# 109               6             25               19               44  ...
# 110               7             20               23               43  ...
# 111               2             23               11               34  ...
# 112               9             19                3               22  ...
# 113               0             22                7               29  ...
#
#     not_finished_instr_women not_finished_instr_total peruvian_men  \
# 0                        554                     1156          630
# 1                         20                       42           22
# 2                          8                       29           21
# 3                         59                      134           75
# 4                         15                       40           25
# ..                       ...                      ...          ...
# 109                       25                       49           25
# 110                       25                       50           25
# 111                       12                       36           24
# 112                        6                       31           25
# 113                        7                       29           22
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 0              580           0             0    399     202      609      0
# 1               20           0             0      0      40        2      0
# 2                8           0             0      0      29        0      0
# 3               59           0             0      0     134        0      0
# 4               15           0             0      0      27       13      0
# ..             ...         ...           ...    ...     ...      ...    ...
# 109             25           0             0      0       6       44      0
# 110             25           0             0      0      34       16      0
# 111             12           0             0      0      30        6      0
# 112              6           0             0      0      18       13      0
# 113              7           0             0      0      25        4      0
#
# [114 rows x 42 columns]

# %%
a = H_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a1=a.dtypes

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object

# %%
Code1= a12.to_excel("Huánuco_finalizado.xlsx")
Code1
