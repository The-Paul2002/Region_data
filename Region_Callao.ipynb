# %% [markdown]
# CALLAO

# %%
import pandas as pd

# %%
callao = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/CALLAO.xlsx")
callao["Region"] = "CALLAO"
Region = callao["Region"]
callao.drop(labels = "Region", axis=1, inplace = True)
callao.insert(0, "Region", Region)
callao.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
callao["District"] = callao["District"].str.upper()
callao["Place"] = callao["Place"].str.upper()
callao["Place"] = callao["Place"].str.strip()

# %%
errors = callao.loc[callao["Place"]=="TOTAL"]
error_list = errors.index.tolist()

# %%
callao_clean = callao.drop(callao.index[error_list])
callao_clean
# Out:
#    Region District       Place   4_6_years_men 4_6_years_women  \
# 0  CALLAO      NaN         NaN             NaN             NaN
# 1  CALLAO      NaN         NaN  De 4 a 6 años              NaN
# 2  CALLAO      NaN         NaN              v.              M.
# 3  CALLAO   CALLAO      CALLAO             563             526
# 4  CALLAO   CALLAO  D.CHUCUITO              16              13
# 5  CALLAO   CALLAO    LA PUNTA               4               2
# 6  CALLAO   CALLAO  BELLAVISTA               2               3
# 7  CALLAO   CALLAO    VILLEGAS               5              10
#
#   4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 0             NaN              NaN              NaN              NaN      NaN
# 1             NaN  De 6 a 14 años               NaN              NaN      NaN
# 2              T.               V.               M.               T.       v.
# 3            1089             2400             2543             4943     1419
# ...

# %%
callao_clean = callao_clean.drop([0, 1, 2],axis=0)
callao_clean
# Out:
#    Region District       Place 4_6_years_men 4_6_years_women 4_6_years_total  \
# 3  CALLAO   CALLAO      CALLAO           563             526            1089
# 4  CALLAO   CALLAO  D.CHUCUITO            16              13              29
# 5  CALLAO   CALLAO    LA PUNTA             4               2               6
# 6  CALLAO   CALLAO  BELLAVISTA             2               3               5
# 7  CALLAO   CALLAO    VILLEGAS             5              10              15
#
#   6_14_years_men 6_14_years_women 6_14_years_total man_read  ...  \
# 3           2400             2543             4943     1419  ...
# 4             84               86              170       57  ...
# 5             23               23               46       18  ...
# 6              8                7               15        2  ...
# 7             13               25               38        6  ...
#
#   not_finished_instr_women not_finished_instr_total peruvian_men  \
# ...

# %%
callao_clean = callao_clean.reset_index()
callao_clean
# Out:
#    index  Region District       Place 4_6_years_men 4_6_years_women  \
# 0      3  CALLAO   CALLAO      CALLAO           563             526
# 1      4  CALLAO   CALLAO  D.CHUCUITO            16              13
# 2      5  CALLAO   CALLAO    LA PUNTA             4               2
# 3      6  CALLAO   CALLAO  BELLAVISTA             2               3
# 4      7  CALLAO   CALLAO    VILLEGAS             5              10
#
#   4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# 0            1089           2400             2543             4943  ...
# 1              29             84               86              170  ...
# 2               6             23               23               46  ...
# 3               5              8                7               15  ...
# 4              15             13               25               38  ...
#
#   not_finished_instr_women not_finished_instr_total peruvian_men  \
# ...

# %%
a = callao_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
a1= a.dtypes

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
Code1= a12.to_excel("Region_Callao.xlsx")
Code1
