# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
tb = pd.read_excel(r"C:\Users\egonz\Dropbox\PC\Desktop\Data/TUMBES.xlsx")
tb["Region"] = "TUMBES"

# %%
region = tb["Region"]
tb.drop(labels = "Region", axis=1, inplace = True)
tb.insert(0, "Region", region)

# %%
tb.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
tb

# %%
tb["District"] = tb["District"].str.upper()
tb["Place"] = tb["Place"].str.upper()

# %%
tb["Place"] = tb["Place"].str.strip()

# %%
errors = tb.loc[tb["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
tb_clean = tb.drop(tb.index[errors_list])
tb_clean
# Out:
#                    Region                District          Place  \
# 0                     NaN                     NaN            NaN
# 1                     NaN                     NaN  DE 4 A 6 AÑOS
# 2                     NaN                     NaN             V.
# 3                 Tumbes                  TUMBES             NaN
# 4                 Tumbes                    TOTAL            NaN
# 5   San Juan de la Virgen   SAN JUAN DE LA VIRGEN            NaN
# 6   San Juan de la Virgen                   TOTAL            NaN
# 7               Corrales   SAN PEDRO DE LOS INCAS            NaN
# 8               Corrales                    TOTAL            NaN
# 9               Sarumilla               SARUMILLA            NaN
# 10              Sarumilla                   TOTAL            NaN
#
#    4_6_years_men 4_6_years_women  4_6_years_total 6_14_years_men  \
# 0            NaN             NaN              NaN            NaN
# 1            NaN             NaN  De 6 a 14 años             NaN
# 2             M.              T.               V.             M.
# 3             68             134              244            221
# 4              0               0                0              0
# 5             36              74              185            132
# 6              0               0                0              0
# 7              4               8              117             43
# 8              0               0                0              0
# 9              1               3               19             15
# 10             0               0                0              0
#
#    6_14_years_women 6_14_years_total man_read  ... not_finished_instr_women  \
# 0               NaN              NaN      NaN  ...                      NaN
# 1               NaN              NaN      NaN  ...                      NaN
# 2                T.               v.       M.  ...                       T.
# 3               465              160      157  ...                      599
# 4                 0                0        0  ...                        0
# 5               317               65       32  ...                      390
# 6                 0                0        0  ...                        0
# 7               160               55       10  ...                      168
# 8                 0                0        0  ...                        0
# 9                34               13        9  ...                       37
# 10                0                0        0  ...                        0
#
#    not_finished_instr_total peruvian_men peruvian_women foreign_men  \
# 0                       NaN          NaN            NaN         NaN
# 1                 Peruanos           NaN    Extranjeros         NaN
# 2                        V.          M.              V.          M.
# 3                       298          277             12          12
# 4                         0            0              0           0
# 5                       186          145             37          23
# 6                         0            0              0           0
# 7                       121           47              0           0
# 8                         0            0              0           0
# 9                        16           12              5           4
# 10                        0            0              0           0
#
#    foreign_women    whites  natives mestizos  blacks
# 0            NaN       NaN      NaN      NaN  TUMBES
# 1            NaN       NaN      NaN      NaN  TUMBES
# 2         Blanca  Indígena  Mestiza    Negra  TUMBES
# 3            111        27      437       24  TUMBES
# 4              0         0        0        0  TUMBES
# 5             53       268       44       26  TUMBES
# 6              0         0        0        0  TUMBES
# 7              6       126       24       15  TUMBES
# 8              0         0        0        0  TUMBES
# 9             11         0       24        2  TUMBES
# 10             0         0        0        0  TUMBES
#
# [11 rows x 41 columns]

# %%
tb_clean = tb_clean.drop([0, 1, 2],axis=0)
tb_clean
# Out:
#                    Region                District Place 4_6_years_men  \
# 3                 Tumbes                  TUMBES    NaN            68
# 4                 Tumbes                    TOTAL   NaN             0
# 5   San Juan de la Virgen   SAN JUAN DE LA VIRGEN   NaN            36
# 6   San Juan de la Virgen                   TOTAL   NaN             0
# 7               Corrales   SAN PEDRO DE LOS INCAS   NaN             4
# 8               Corrales                    TOTAL   NaN             0
# 9               Sarumilla               SARUMILLA   NaN             1
# 10              Sarumilla                   TOTAL   NaN             0
#
#    4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 3              134             244            221              465
# 4                0               0              0                0
# 5               74             185            132              317
# 6                0               0              0                0
# 7                8             117             43              160
# 8                0               0              0                0
# 9                3              19             15               34
# 10               0               0              0                0
#
#    6_14_years_total man_read  ... not_finished_instr_women  \
# 3               160      157  ...                      599
# 4                 0        0  ...                        0
# 5                65       32  ...                      390
# 6                 0        0  ...                        0
# 7                55       10  ...                      168
# 8                 0        0  ...                        0
# 9                13        9  ...                       37
# 10                0        0  ...                        0
#
#    not_finished_instr_total peruvian_men peruvian_women foreign_men  \
# 3                       298          277             12          12
# 4                         0            0              0           0
# 5                       186          145             37          23
# 6                         0            0              0           0
# 7                       121           47              0           0
# 8                         0            0              0           0
# 9                        16           12              5           4
# 10                        0            0              0           0
#
#    foreign_women whites natives mestizos  blacks
# 3            111     27     437       24  TUMBES
# 4              0      0       0        0  TUMBES
# 5             53    268      44       26  TUMBES
# 6              0      0       0        0  TUMBES
# 7              6    126      24       15  TUMBES
# 8              0      0       0        0  TUMBES
# 9             11      0      24        2  TUMBES
# 10             0      0       0        0  TUMBES
#
# [8 rows x 41 columns]

# %%
tb_clean = tb_clean.reset_index()
tb_clean
# Out:
#    index                 Region                District Place 4_6_years_men  \
# 0      3                Tumbes                  TUMBES    NaN            68
# 1      4                Tumbes                    TOTAL   NaN             0
# 2      5  San Juan de la Virgen   SAN JUAN DE LA VIRGEN   NaN            36
# 3      6  San Juan de la Virgen                   TOTAL   NaN             0
# 4      7              Corrales   SAN PEDRO DE LOS INCAS   NaN             4
# 5      8              Corrales                    TOTAL   NaN             0
# 6      9              Sarumilla               SARUMILLA   NaN             1
# 7     10              Sarumilla                   TOTAL   NaN             0
#
#   4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0             134             244            221              465
# 1               0               0              0                0
# 2              74             185            132              317
# 3               0               0              0                0
# 4               8             117             43              160
# 5               0               0              0                0
# 6               3              19             15               34
# 7               0               0              0                0
#
#   6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0              160  ...                      599                      298
# 1                0  ...                        0                        0
# 2               65  ...                      390                      186
# 3                0  ...                        0                        0
# 4               55  ...                      168                      121
# 5                0  ...                        0                        0
# 6               13  ...                       37                       16
# 7                0  ...                        0                        0
#
#   peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0          277             12          12           111     27     437
# 1            0              0           0             0      0       0
# 2          145             37          23            53    268      44
# 3            0              0           0             0      0       0
# 4           47              0           0             6    126      24
# 5            0              0           0             0      0       0
# 6           12              5           4            11      0      24
# 7            0              0           0             0      0       0
#
#   mestizos  blacks
# 0       24  TUMBES
# 1        0  TUMBES
# 2       26  TUMBES
# 3        0  TUMBES
# 4       15  TUMBES
# 5        0  TUMBES
# 6        2  TUMBES
# 7        0  TUMBES
#
# [8 rows x 42 columns]

# %%
a = tb_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                       object
# District                     object
# Place                       float64
# 4_6_years_men                 int64
# 4_6_years_women               int64
# 4_6_years_total               int64
# 6_14_years_men                int64
# 6_14_years_women              int64
# 6_14_years_total              int64
# man_read                      int64
# women_read                    int64
# total_read                    int64
# men_not_read                  int64
# women_not_read                int64
# total_not_read                int64
# man_write                     int64
# women_write                   int64
# total_write                   int64
# men_not_write                 int64
# women_not_write               int64
# total_not_write               int64
# instruction_men               int64
# instruction_women             int64
# instruction_total             int64
# no_instruction_men            int64
# no_instruction_women          int64
# no_instruction_total          int64
# finished_instr_men            int64
# finished_instr_women          int64
# finished_instr_total          int64
# not_finished_instr_men        int64
# not_finished_instr_women      int64
# not_finished_instr_total      int64
# peruvian_men                  int64
# peruvian_women                int64
# foreign_men                   int64
# foreign_women                 int64
# whites                        int64
# natives                       int64
# mestizos                      int64
# blacks                       object
# dtype: object

# %%
Code1= a12.to_excel("Region_Tumbes.xlsx")
Code1
