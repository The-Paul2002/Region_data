# %%
import pandas as pd

# %%
ar = pd.read_excel(r"C:\Users\egonz\Dropbox\PC\Desktop\Data/AREQUIPA.xlsx")
ar["Region"] = "AREQUIPA"

# %%
region = ar["Region"]
ar.drop(labels = "Region", axis=1, inplace = True)
ar.insert(0, "Region", region)

# %%
ar.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
ar

# %%
ar["District"] = ar["District"].str.upper()
ar["Place"] = ar["Place"].str.upper()

# %%
ar["Place"] = ar["Place"].str.strip()

# %%
errors = ar.loc[ar["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
ar_clean = ar.drop(ar.index[errors_list])
ar_clean
# Out:
#          Region     District          Place 4_6_years_men 4_6_years_women  \
# 0           NaN          NaN            NaN           NaN             NaN
# 1           NaN          NaN  DE 4 A 6 AÑOS           NaN             NaN
# 2           NaN          NaN             V.            M.              T.
# 3      AREQUIPA  P. AREQUIPA            NaN           396             803
# 4      AREQUIPA        TOTAL            NaN             0               0
# ..          ...          ...            ...           ...             ...
# 265  HUANUHUANU        TOTAL            NaN             0               0
# 266    ATIQUIPA  P. ATIQUIPA            NaN             1               6
# 267    ATIQUIPA        TOTAL            NaN             0               0
# 268       ATICO     P. ATICO            NaN             4              10
# 269       ATICO        TOTAL            NaN             0               0
#
#      4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  \
# 0                NaN            NaN              NaN              NaN
# 1    De 6 a 14 años             NaN              NaN              NaN
# 2                 V.             M.               T.               v.
# 3               2395           2306             4701             1372
# 4                  0              0                0                0
# ..               ...            ...              ...              ...
# 265                0              0                0                0
# 266               20             13               33                0
# 267                0              0                0                0
# 268               46             10               56                0
# 269                0              0                0                0
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                Peruanos
# 2         M.  ...                       T.                       V.
# 3       1283  ...                     4882                     2793
# 4          0  ...                        0                        0
# ..       ...  ...                      ...                      ...
# 265        0  ...                        0                        0
# 266        0  ...                       39                       25
# 267        0  ...                        0                        0
# 268        0  ...                       66                       52
# 269        0  ...                        0                        0
#
#     peruvian_men peruvian_women foreign_men foreign_women    whites  natives  \
# 0            NaN            NaN         NaN           NaN       NaN      NaN
# 1            NaN    Extranjeros         NaN           NaN       NaN      NaN
# 2            M.              V.          M.        Blanca  Indígena  Mestiza
# 3           1689              9          13          2153      1996     1176
# 4              0              0           0             0         0        0
# ..           ...            ...         ...           ...       ...      ...
# 265            0              0           0             0         0        0
# 266           14              0           0            12         0       27
# 267            0              0           0             0         0        0
# 268           14              0           0            40         0       26
# 269            0              0           0             0         0        0
#
#     mestizos    blacks
# 0        NaN  AREQUIPA
# 1        NaN  AREQUIPA
# 2      Negra  AREQUIPA
# 3        179  AREQUIPA
# 4          0  AREQUIPA
# ..       ...       ...
# 265        0  AREQUIPA
# 266        0  AREQUIPA
# 267        0  AREQUIPA
# 268        0  AREQUIPA
# 269        0  AREQUIPA
#
# [270 rows x 41 columns]

# %%
ar_clean = ar_clean.drop([0, 1, 2],axis=0)
ar_clean
# Out:
#          Region       District Place 4_6_years_men 4_6_years_women  \
# 3      AREQUIPA    P. AREQUIPA   NaN           396             803
# 4      AREQUIPA          TOTAL   NaN             0               0
# 5    MIRAFLORES  P. MIRAFLORES   NaN            60             120
# 6    MIRAFLORES     LAMBRAMANI   NaN             3              10
# 7    MIRAFLORES        CHILINA   NaN             3               5
# ..          ...            ...   ...           ...             ...
# 265  HUANUHUANU          TOTAL   NaN             0               0
# 266    ATIQUIPA    P. ATIQUIPA   NaN             1               6
# 267    ATIQUIPA          TOTAL   NaN             0               0
# 268       ATICO       P. ATICO   NaN             4              10
# 269       ATICO          TOTAL   NaN             0               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3              2395           2306             4701             1372     1283
# 4                 0              0                0                0        0
# 5               336            287              623              109      128
# 6                26             17               43               16        7
# 7                 9              9               18                4        0
# ..              ...            ...              ...              ...      ...
# 265               0              0                0                0        0
# 266              20             13               33                0        0
# 267               0              0                0                0        0
# 268              46             10               56                0        0
# 269               0              0                0                0        0
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                     4882                     2793         1689
# 4    ...                        0                        0            0
# 5    ...                      735                      396          347
# 6    ...                       53                       33           20
# 7    ...                       23                       11           12
# ..   ...                      ...                      ...          ...
# 265  ...                        0                        0            0
# 266  ...                       39                       25           14
# 267  ...                        0                        0            0
# 268  ...                       66                       52           14
# 269  ...                        0                        0            0
#
#     peruvian_women foreign_men foreign_women whites natives mestizos    blacks
# 3                9          13          2153   1996    1176      179  AREQUIPA
# 4                0           0             0      0       0        0  AREQUIPA
# 5                0           0           282    208     253        0  AREQUIPA
# 6                0           0            41      2      10        0  AREQUIPA
# 7                0           0             0      0      23        0  AREQUIPA
# ..             ...         ...           ...    ...     ...      ...       ...
# 265              0           0             0      0       0        0  AREQUIPA
# 266              0           0            12      0      27        0  AREQUIPA
# 267              0           0             0      0       0        0  AREQUIPA
# 268              0           0            40      0      26        0  AREQUIPA
# 269              0           0             0      0       0        0  AREQUIPA
#
# [267 rows x 41 columns]

# %%
ar_clean = ar_clean.reset_index()
ar_clean
# Out:
#      index      Region       District Place 4_6_years_men 4_6_years_women  \
# 0        3    AREQUIPA    P. AREQUIPA   NaN           396             803
# 1        4    AREQUIPA          TOTAL   NaN             0               0
# 2        5  MIRAFLORES  P. MIRAFLORES   NaN            60             120
# 3        6  MIRAFLORES     LAMBRAMANI   NaN             3              10
# 4        7  MIRAFLORES        CHILINA   NaN             3               5
# ..     ...         ...            ...   ...           ...             ...
# 262    265  HUANUHUANU          TOTAL   NaN             0               0
# 263    266    ATIQUIPA    P. ATIQUIPA   NaN             1               6
# 264    267    ATIQUIPA          TOTAL   NaN             0               0
# 265    268       ATICO       P. ATICO   NaN             4              10
# 266    269       ATICO          TOTAL   NaN             0               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# 0              2395           2306             4701             1372  ...
# 1                 0              0                0                0  ...
# 2               336            287              623              109  ...
# 3                26             17               43               16  ...
# 4                 9              9               18                4  ...
# ..              ...            ...              ...              ...  ...
# 262               0              0                0                0  ...
# 263              20             13               33                0  ...
# 264               0              0                0                0  ...
# 265              46             10               56                0  ...
# 266               0              0                0                0  ...
#
#     not_finished_instr_women not_finished_instr_total peruvian_men  \
# 0                       4882                     2793         1689
# 1                          0                        0            0
# 2                        735                      396          347
# 3                         53                       33           20
# 4                         23                       11           12
# ..                       ...                      ...          ...
# 262                        0                        0            0
# 263                       39                       25           14
# 264                        0                        0            0
# 265                       66                       52           14
# 266                        0                        0            0
#
#     peruvian_women foreign_men foreign_women whites natives mestizos    blacks
# 0                9          13          2153   1996    1176      179  AREQUIPA
# 1                0           0             0      0       0        0  AREQUIPA
# 2                0           0           282    208     253        0  AREQUIPA
# 3                0           0            41      2      10        0  AREQUIPA
# 4                0           0             0      0      23        0  AREQUIPA
# ..             ...         ...           ...    ...     ...      ...       ...
# 262              0           0             0      0       0        0  AREQUIPA
# 263              0           0            12      0      27        0  AREQUIPA
# 264              0           0             0      0       0        0  AREQUIPA
# 265              0           0            40      0      26        0  AREQUIPA
# 266              0           0             0      0       0        0  AREQUIPA
#
# [267 rows x 42 columns]

# %%
a = ar_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                       object
# District                     object
# Place                       float64
# 4_6_years_men               float64
# 4_6_years_women             float64
# 4_6_years_total             float64
# 6_14_years_men              float64
# 6_14_years_women            float64
# 6_14_years_total            float64
# man_read                    float64
# women_read                  float64
# total_read                  float64
# men_not_read                float64
# women_not_read              float64
# total_not_read              float64
# man_write                   float64
# women_write                 float64
# total_write                 float64
# men_not_write               float64
# women_not_write             float64
# total_not_write             float64
# instruction_men             float64
# instruction_women           float64
# instruction_total           float64
# no_instruction_men          float64
# no_instruction_women        float64
# no_instruction_total        float64
# finished_instr_men          float64
# finished_instr_women        float64
# finished_instr_total        float64
# not_finished_instr_men      float64
# not_finished_instr_women    float64
# not_finished_instr_total    float64
# peruvian_men                float64
# peruvian_women              float64
# foreign_men                 float64
# foreign_women               float64
# whites                      float64
# natives                     float64
# mestizos                    float64
# blacks                       object
# dtype: object

# %% [markdown]
# ## Contiene columnas combinadas EN LLUTA por eso los toma como float

# %%
Code1= a12.to_excel("Region_Arequipa.xlsx")
Code1
