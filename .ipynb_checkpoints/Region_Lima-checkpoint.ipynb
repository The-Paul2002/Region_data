# %% [markdown]
# LIMA CENSO 1902

# %%
import pandas as pd

# %%
lima = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/LIMA_FINALIZADO.xlsx")
lima["Region"] = "LIMA"
Region = lima["Region"]
lima.drop(labels = "Region", axis=1, inplace = True)
lima.insert(0, "Region", Region)
lima.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
lima["District"] =lima["District"].str.upper()
lima["Place"] = lima["Place"].str.upper()

# %%
lima["Place"] = lima["Place"].str.strip()
# Find errors with string = Total
errors = lima.loc[lima["Place"]=="TOTAL"]
error_list = errors.index.tolist()

lima_clean = lima.drop(lima.index[error_list])
lima_clean
# Out:
#     Region  District              Place   4_6_years_men 4_6_years_women  \
# 0     LIMA       NaN                NaN             NaN             NaN
# 1     LIMA       NaN                NaN  De 4 a 6 años              NaN
# 2     LIMA       NaN                NaN              v.              M.
# 3     LIMA      LIMA         CUARTEL 10             396             405
# 4     LIMA      LIMA         CUARTEL 20             423             423
# ..     ...       ...                ...             ...             ...
# 366   LIMA  SAN LUIS           QUEBRADA               4               5
# 367   LIMA  SAN LUIS        CASA BLANCA               3               2
# 368   LIMA  SAN LUIS  SAN JUAN DE ARONA               8               7
# 369   LIMA  SAN LUIS      SANTA BÁRBARA               1              10
# 370   LIMA  SAN LUIS              HUACA               5               4
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               801             1707             1739             3446
# 4               846             1752             1979             3731
# ..              ...              ...              ...              ...
# 366               9               21               20               41
# 367               5               17                8               25
# 368              15               37               36               73
# 369              11               27               19               46
# 370               9               17               10               27
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3       1319  ...                     1779                     3536
# 4       1227  ...                     2168                     4104
# ..       ...  ...                      ...                      ...
# 366        2  ...                       25                       50
# 367        6  ...                       10                       30
# 368        1  ...                       43                       88
# 369        3  ...                       29                       63
# 370        3  ...                       14                       36
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           2062           2013           41           131    2125       946
# 4           2115           2296           60           106    1789      1141
# ..           ...            ...          ...           ...     ...       ...
# 366           25             25            0             0       3        28
# 367           20             10            0             0       1         7
# 368           45             43            0             0       0        24
# 369           34             29            0             0       0        20
# 370           22             14            0             0       0         8
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1112    164
# 4       1448    199
# ..       ...    ...
# 366        6     13
# 367       17      5
# 368       10     54
# 369       30     13
# 370       16     12
#
# [314 rows x 41 columns]

# %%
lima_clean = lima_clean.drop([0, 1, 2],axis=0)
lima_clean
# Out:
#     Region  District              Place 4_6_years_men 4_6_years_women  \
# 3     LIMA      LIMA         CUARTEL 10           396             405
# 4     LIMA      LIMA         CUARTEL 20           423             423
# 5     LIMA      LIMA         CUARTEL 30           455             437
# 6     LIMA      LIMA         CUARTEL 40           432             368
# 7     LIMA      LIMA         CUARTEL 50           373             407
# ..     ...       ...                ...           ...             ...
# 366   LIMA  SAN LUIS           QUEBRADA             4               5
# 367   LIMA  SAN LUIS        CASA BLANCA             3               2
# 368   LIMA  SAN LUIS  SAN JUAN DE ARONA             8               7
# 369   LIMA  SAN LUIS      SANTA BÁRBARA             1              10
# 370   LIMA  SAN LUIS              HUACA             5               4
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               801           1707             1739             3446     1319
# 4               846           1752             1979             3731     1227
# 5               892           1794             1892             3686      985
# 6               800           1685             1752             3437     1389
# 7               780           1740             1900             3640     1248
# ..              ...            ...              ...              ...      ...
# 366               9             21               20               41        2
# 367               5             17                8               25        6
# 368              15             37               36               73        1
# 369              11             27               19               46        3
# 370               9             17               10               27        3
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                     1779                     3536         2062
# 4    ...                     2168                     4104         2115
# 5    ...                     2061                     4152         2239
# 6    ...                     1868                     3728         1985
# 7    ...                     2046                     3937         2110
# ..   ...                      ...                      ...          ...
# 366  ...                       25                       50           25
# 367  ...                       10                       30           20
# 368  ...                       43                       88           45
# 369  ...                       29                       63           34
# 370  ...                       14                       36           22
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3             2013          41           131   2125     946     1112    164
# 4             2296          60           106   1789    1141     1448    199
# 5             2318          10            11   1234    1006     2054    284
# 6             2018         132           102   1845     548     1482    362
# 7             2300           3             7   2029     789     1388    214
# ..             ...         ...           ...    ...     ...      ...    ...
# 366             25           0             0      3      28        6     13
# 367             10           0             0      1       7       17      5
# 368             43           0             0      0      24       10     54
# 369             29           0             0      0      20       30     13
# 370             14           0             0      0       8       16     12
#
# [311 rows x 41 columns]

# %%
lima_clean = lima_clean.reset_index()
lima_clean
# Out:
#      index Region  District              Place 4_6_years_men 4_6_years_women  \
# 0        3   LIMA      LIMA         CUARTEL 10           396             405
# 1        4   LIMA      LIMA         CUARTEL 20           423             423
# 2        5   LIMA      LIMA         CUARTEL 30           455             437
# 3        6   LIMA      LIMA         CUARTEL 40           432             368
# 4        7   LIMA      LIMA         CUARTEL 50           373             407
# ..     ...    ...       ...                ...           ...             ...
# 306    366   LIMA  SAN LUIS           QUEBRADA             4               5
# 307    367   LIMA  SAN LUIS        CASA BLANCA             3               2
# 308    368   LIMA  SAN LUIS  SAN JUAN DE ARONA             8               7
# 309    369   LIMA  SAN LUIS      SANTA BÁRBARA             1              10
# 310    370   LIMA  SAN LUIS              HUACA             5               4
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# 0               801           1707             1739             3446  ...
# 1               846           1752             1979             3731  ...
# 2               892           1794             1892             3686  ...
# 3               800           1685             1752             3437  ...
# 4               780           1740             1900             3640  ...
# ..              ...            ...              ...              ...  ...
# 306               9             21               20               41  ...
# 307               5             17                8               25  ...
# 308              15             37               36               73  ...
# 309              11             27               19               46  ...
# 310               9             17               10               27  ...
#
#     not_finished_instr_women not_finished_instr_total peruvian_men  \
# 0                       1779                     3536         2062
# 1                       2168                     4104         2115
# 2                       2061                     4152         2239
# 3                       1868                     3728         1985
# 4                       2046                     3937         2110
# ..                       ...                      ...          ...
# 306                       25                       50           25
# 307                       10                       30           20
# 308                       43                       88           45
# 309                       29                       63           34
# 310                       14                       36           22
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 0             2013          41           131   2125     946     1112    164
# 1             2296          60           106   1789    1141     1448    199
# 2             2318          10            11   1234    1006     2054    284
# 3             2018         132           102   1845     548     1482    362
# 4             2300           3             7   2029     789     1388    214
# ..             ...         ...           ...    ...     ...      ...    ...
# 306             25           0             0      3      28        6     13
# 307             10           0             0      1       7       17      5
# 308             43           0             0      0      24       10     54
# 309             29           0             0      0      20       30     13
# 310             14           0             0      0       8       16     12
#
# [311 rows x 42 columns]

# %%
a= lima_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a= a.infer_objects()
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object

# %%
Code1= a.to_excel("Region_Lima.xlsx") 
Code1

# %%
a12.

# %%
Code1= B01.to_excel("Lima_finalizado.xlsx")
Code1
