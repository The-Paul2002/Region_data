# %%
import pandas as pd

# %% [markdown]
# ###

# %%
ancash = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/ANCASH_FINALIZADO.xlsx")
ancash["Region"] = "ANCASH"
Region = ancash["Region"]
ancash.drop(labels = "Region", axis=1, inplace = True)
ancash.insert(0, "Region", Region)
ancash.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
region = ancash["Region"]

# %%
ancash["District"] =ancash["District"].str.upper()
ancash["Place"] = ancash["Place"].str.upper()

# %%
ancash["Place"] = ancash["Place"].str.strip()
# Find errors with string = Total
errors =ancash.loc[ancash["Place"]=="TOTAL"]
error_list = errors.index.tolist()

ancash_clean = ancash.drop(ancash.index[error_list])
ancash_clean
# Out:
#      Region  District                Place   4_6_years_men 4_6_years_women  \
# 0    ANCASH       NaN                  NaN             NaN             NaN
# 1    ANCASH       NaN                  NaN  De 4 a 6 años              NaN
# 2    ANCASH       NaN                  NaN              v.              M.
# 3    ANCASH    HUARAZ           CD. HUARÁZ              84              99
# 4    ANCASH    HUARAZ             C.CURUAS              22               8
# ..      ...       ...                  ...             ...             ...
# 399  ANCASH      OYÓN                UTUTO              12               6
# 400  ANCASH      OYÓN  C.POMAMAYO Y ANEXOS              11              10
# 402  ANCASH  CHIQUIÁN           P.CHIQUIAN               8               0
# 403  ANCASH  CHIQUIÁN              A.CARCA               0               0
# 405  ANCASH     TAUCA              P.TAUCA              52              45
#
# ...

# %%
ancash_clean = ancash_clean.drop([0, 1, 2],axis=0)
ancash_clean
# Out:
#      Region  District                Place 4_6_years_men 4_6_years_women  \
# 3    ANCASH    HUARAZ           CD. HUARÁZ            84              99
# 4    ANCASH    HUARAZ             C.CURUAS            22               8
# 5    ANCASH    HUARAZ            ACOVICHAY             0               9
# 6    ANCASH    HUARAZ               PACHAY            15              16
# 7    ANCASH    HUARAZ            ALIPALLAN             3               7
# ..      ...       ...                  ...           ...             ...
# 399  ANCASH      OYÓN                UTUTO            12               6
# 400  ANCASH      OYÓN  C.POMAMAYO Y ANEXOS            11              10
# 402  ANCASH  CHIQUIÁN           P.CHIQUIAN             8               0
# 403  ANCASH  CHIQUIÁN              A.CARCA             0               0
# 405  ANCASH     TAUCA              P.TAUCA            52              45
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# ...

# %%
ancash_clean = ancash_clean.reset_index()
ancash_clean
# Out:
#      index  Region  District                Place 4_6_years_men  \
# 0        3  ANCASH    HUARAZ           CD. HUARÁZ            84
# 1        4  ANCASH    HUARAZ             C.CURUAS            22
# 2        5  ANCASH    HUARAZ            ACOVICHAY             0
# 3        6  ANCASH    HUARAZ               PACHAY            15
# 4        7  ANCASH    HUARAZ            ALIPALLAN             3
# ..     ...     ...       ...                  ...           ...
# 335    399  ANCASH      OYÓN                UTUTO            12
# 336    400  ANCASH      OYÓN  C.POMAMAYO Y ANEXOS            11
# 337    402  ANCASH  CHIQUIÁN           P.CHIQUIAN             8
# 338    403  ANCASH  CHIQUIÁN              A.CARCA             0
# 339    405  ANCASH     TAUCA              P.TAUCA            52
#
#     4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0                99             183            585              453
# ...

# %%
a = ancash_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a1=a.dtypes

# %%
aea= a.infer_objects()
aea.dtypes
# Out:
# Region                       object
# District                     object
# Place                        object
# 4_6_years_men                 int64
# 4_6_years_women               int64
# 4_6_years_total               int64
# 6_14_years_men                int64
# 6_14_years_women              int64
# 6_14_years_total              int64
# man_read                      int64
# women_read                  float64
# total_read                    int64
# men_not_read                  int64
# women_not_read              float64
# total_not_read                int64
# man_write                     int64
# women_write                   int64
# total_write                   int64
# men_not_write                 int64
# women_not_write               int64
# total_not_write               int64
# instruction_men               int64
# instruction_women             int64
# instruction_total             int64
# no_instruction_men            int64
# no_instruction_women          int64
# ...

# %%
aea.women_read = aea.women_read.fillna(0)
aea.women_not_read = aea.women_not_read.fillna(0)
aea.finished_instr_total = aea.finished_instr_total.fillna(0)
aea.mestizos = aea.mestizos.fillna(0)

# %%
aea.women_read = aea.women_read.astype(int)
aea.women_not_read = aea.women_not_read.astype(int)
aea.finished_instr_total = aea.finished_instr_total.astype(int)
aea.mestizos = aea.mestizos.astype(int)

# %%
aea1 = aea.dtypes
aea1
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int32
# total_read                   int64
# men_not_read                 int64
# women_not_read               int32
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
aea1
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int32
# total_read                   int64
# men_not_read                 int64
# women_not_read               int32
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
a12= aea.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int32
# total_read                   int64
# men_not_read                 int64
# women_not_read               int32
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
a12
# Out:
#      Region  District                Place  4_6_years_men  4_6_years_women  \
# 0    ANCASH    HUARAZ           CD. HUARÁZ             84               99
# 1    ANCASH    HUARAZ             C.CURUAS             22                8
# 2    ANCASH    HUARAZ            ACOVICHAY              0                9
# 3    ANCASH    HUARAZ               PACHAY             15               16
# 4    ANCASH    HUARAZ            ALIPALLAN              3                7
# ..      ...       ...                  ...            ...              ...
# 335  ANCASH      OYÓN                UTUTO             12                6
# 336  ANCASH      OYÓN  C.POMAMAYO Y ANEXOS             11               10
# 337  ANCASH  CHIQUIÁN           P.CHIQUIAN              8                0
# 338  ANCASH  CHIQUIÁN              A.CARCA              0                0
# 339  ANCASH     TAUCA              P.TAUCA             52               45
#
# ...

# %%
Code1= a12.to_excel("Region_Ancash.xlsx")
Code1
