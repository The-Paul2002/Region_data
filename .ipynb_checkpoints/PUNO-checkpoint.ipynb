# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
puno = pd.read_excel(r"C:\Users\egonz\Desktop\Data/PUNO.xlsx")
puno["Region"] = "PUNO"
region = puno["Region"]
puno.drop(labels = "Region", axis=1, inplace = True)
puno.insert(0, "Region", region)
puno.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
puno
# Out:
#     Region District       Place   4_6_years_men 4_6_years_women  \
# 0     PUNO      NaN         NaN             NaN             NaN
# 1     PUNO      NaN         NaN  De 4 a 6 años              NaN
# 2     PUNO      NaN         NaN              v.              M.
# 3     PUNO     PUNO      P.Puno              63              55
# 4     PUNO     PUNO     C.Checa               8               2
# ..     ...      ...         ...             ...             ...
# 289   PUNO     POTO     P. Poto              14               4
# 290   PUNO     POTO       TOTAL               0               0
# 291   PUNO    PHARA    P. Phara               0               5
# 292   PUNO    PHARA  C. Limbani               1               0
# 293   PUNO    PHARA       TOTAL               0               0
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# ...

# %%
puno["District"] = puno["District"].str.upper()
puno["Place"] = puno["Place"].str.upper()

# %%
puno["Place"] = puno["Place"].str.strip()

# %%
errors = puno.loc[puno["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
puno_clean = puno.drop(puno.index[errors_list])
puno_clean
# Out:
#     Region District         Place   4_6_years_men 4_6_years_women  \
# 0     PUNO      NaN           NaN             NaN             NaN
# 1     PUNO      NaN           NaN  De 4 a 6 años              NaN
# 2     PUNO      NaN           NaN              v.              M.
# 3     PUNO     PUNO        P.PUNO              63              55
# 4     PUNO     PUNO       C.CHECA               8               2
# ..     ...      ...           ...             ...             ...
# 285   PUNO   QUIACA  C. TAMBOPATA               5               3
# 287   PUNO     SINA       P. SINA               8               8
# 289   PUNO     POTO       P. POTO              14               4
# 291   PUNO    PHARA      P. PHARA               0               5
# 292   PUNO    PHARA    C. LIMBANI               1               0
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# ...

# %%
puno_clean = puno_clean.drop([0, 1, 2],axis=0)
puno_clean
# Out:
#     Region District         Place 4_6_years_men 4_6_years_women  \
# 3     PUNO     PUNO        P.PUNO            63              55
# 4     PUNO     PUNO       C.CHECA             8               2
# 5     PUNO     PUNO         PAIRA             3               3
# 6     PUNO     PUNO       HUARAYA             2               1
# 7     PUNO     PUNO         MANTO             2               5
# ..     ...      ...           ...           ...             ...
# 285   PUNO   QUIACA  C. TAMBOPATA             5               3
# 287   PUNO     SINA       P. SINA             8               8
# 289   PUNO     POTO       P. POTO            14               4
# 291   PUNO    PHARA      P. PHARA             0               5
# 292   PUNO    PHARA    C. LIMBANI             1               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               118            301              304              605      173
# ...

# %%
puno_clean = puno_clean.reset_index()
puno_clean
# Out:
#      index Region District         Place 4_6_years_men 4_6_years_women  \
# 0        3   PUNO     PUNO        P.PUNO            63              55
# 1        4   PUNO     PUNO       C.CHECA             8               2
# 2        5   PUNO     PUNO         PAIRA             3               3
# 3        6   PUNO     PUNO       HUARAYA             2               1
# 4        7   PUNO     PUNO         MANTO             2               5
# ..     ...    ...      ...           ...           ...             ...
# 215    285   PUNO   QUIACA  C. TAMBOPATA             5               3
# 216    287   PUNO     SINA       P. SINA             8               8
# 217    289   PUNO     POTO       P. POTO            14               4
# 218    291   PUNO    PHARA      P. PHARA             0               5
# 219    292   PUNO    PHARA    C. LIMBANI             1               0
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# ...

# %%
a = puno_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                       object
# District                     object
# Place                        object
# 4_6_years_men               float64
# 4_6_years_women             float64
# 4_6_years_total             float64
# 6_14_years_men              float64
# 6_14_years_women            float64
# 6_14_years_total            float64
# man_read                    float64
# women_read                  float64
# total_read                  float64
# men_not_read                float64
# women_not_read              float64
# total_not_read              float64
# man_write                   float64
# women_write                 float64
# total_write                 float64
# men_not_write               float64
# women_not_write             float64
# total_not_write             float64
# instruction_men             float64
# instruction_women           float64
# instruction_total           float64
# no_instruction_men          float64
# no_instruction_women        float64
# ...

# %%
a12['blacks'] = a12['blacks'].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6840/2442383755.py in <module>
# ----> 1 a12['blacks'] = a12['blacks'].astype(np.int64)
#
# NameError: name 'np' is not defined

# %%
import numpy as pd

# %%
a12['blacks'] = a12['blacks'].fillna(0).astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6840/922356856.py in <module>
# ----> 1 a12['blacks'] = a12['blacks'].fillna(0).astype(np.int64)
#
# NameError: name 'np' is not defined

# %%
import numpy as pd

# %%
Code1= a12.to_excel("Region_Amazonas.xlsx")
Code1
