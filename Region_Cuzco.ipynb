# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
cu = pd.read_excel(r"C:\Users\egonz\Dropbox\PC\Desktop\Data/CUZCO.xlsx")
cu["Region"] = "CUZCO"

# %%
region = cu["Region"]

# %%
cu.drop(labels = "Region", axis=1, inplace = True)
cu.insert(0, "Region", region)

# %%
cu.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
cu
# Out:
#     Region    District        Place   4_6_years_men 4_6_years_women  \
# 0    CUZCO         NaN          NaN             NaN             NaN
# 1    CUZCO         NaN          NaN  De 4 a 6 años              NaN
# 2    CUZCO         NaN          NaN              v.              M.
# 3    CUZCO       Cuzco     P. Cuzco              75              74
# 4    CUZCO       Cuzco        Total               0               0
# ..     ...         ...          ...             ...             ...
# 287  CUZCO  Vilcabamba        Total               0               0
# 288  CUZCO   Huayopata  P.Huayopata               2               3
# 289  CUZCO   Huayopata        Total               0               0
# 290  CUZCO    Echarate   P.Echarate               5               6
# 291  CUZCO    Echarate        Total               0               0
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               149             1461             1436             2897
# 4                 0                0                0                0
# ..              ...              ...              ...              ...
# 287               0                0                0                0
# 288               5               38               38               76
# 289               0                0                0                0
# 290              11               45               39               84
# 291               0                0                0                0
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3        867  ...                     1369                     2751
# 4          0  ...                        0                        0
# ..       ...  ...                      ...                      ...
# 287        0  ...                        0                        0
# 288       18  ...                       41                       81
# 289        0  ...                        0                        0
# 290       30  ...                       45                       95
# 291        0  ...                        0                        0
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           1532           1502            4             8    1461       544
# 4              0              0            0             0       0         0
# ..           ...            ...          ...           ...     ...       ...
# 287            0              0            0             0       0         0
# 288           40             41            0             0      81         0
# 289            0              0            0             0       0         0
# 290           50             45            0             0      53        42
# 291            0              0            0             0       0         0
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1038      3
# 4          0      0
# ..       ...    ...
# 287        0      0
# 288        0      0
# 289        0      0
# 290        0      0
# 291        0      0
#
# [292 rows x 41 columns]
#     Region    District        Place   4_6_years_men 4_6_years_women  \
# 0    CUZCO         NaN          NaN             NaN             NaN
# 1    CUZCO         NaN          NaN  De 4 a 6 años              NaN
# 2    CUZCO         NaN          NaN              v.              M.
# 3    CUZCO       Cuzco     P. Cuzco              75              74
# 4    CUZCO       Cuzco        Total               0               0
# ..     ...         ...          ...             ...             ...
# 287  CUZCO  Vilcabamba        Total               0               0
# 288  CUZCO   Huayopata  P.Huayopata               2               3
# 289  CUZCO   Huayopata        Total               0               0
# 290  CUZCO    Echarate   P.Echarate               5               6
# 291  CUZCO    Echarate        Total               0               0
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               149             1461             1436             2897
# 4                 0                0                0                0
# ..              ...              ...              ...              ...
# 287               0                0                0                0
# 288               5               38               38               76
# 289               0                0                0                0
# 290              11               45               39               84
# 291               0                0                0                0
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3        867  ...                     1369                     2751
# 4          0  ...                        0                        0
# ..       ...  ...                      ...                      ...
# 287        0  ...                        0                        0
# 288       18  ...                       41                       81
# 289        0  ...                        0                        0
# 290       30  ...                       45                       95
# 291        0  ...                        0                        0
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           1532           1502            4             8    1461       544
# 4              0              0            0             0       0         0
# ..           ...            ...          ...           ...     ...       ...
# 287            0              0            0             0       0         0
# 288           40             41            0             0      81         0
# 289            0              0            0             0       0         0
# 290           50             45            0             0      53        42
# 291            0              0            0             0       0         0
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1038      3
# 4          0      0
# ..       ...    ...
# 287        0      0
# 288        0      0
# 289        0      0
# 290        0      0
# 291        0      0
#
# [292 rows x 41 columns]

# %%
cu["District"] = cu["District"].str.upper()
cu["Place"] = cu["Place"].str.upper()

# %%
cu["Place"] = cu["Place"].str.strip()

# %%
errors = cu.loc[cu["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
cu_clean = cu.drop(cu.index[errors_list])
cu_clean
# Out:
#     Region      District            Place   4_6_years_men 4_6_years_women  \
# 0    CUZCO           NaN              NaN             NaN             NaN
# 1    CUZCO           NaN              NaN  De 4 a 6 años              NaN
# 2    CUZCO           NaN              NaN              v.              M.
# 3    CUZCO         CUZCO         P. CUZCO              75              74
# 5    CUZCO  SAN GERONIMO  P. SAN GERONIMO              69              38
# ..     ...           ...              ...             ...             ...
# 284  CUZCO    VILCABAMBA     P.VILCABAMBA              13              21
# 285  CUZCO    VILCABAMBA          C.LUCMA               2               1
# 286  CUZCO    VILCABAMBA          PUCYURA               6               5
# 288  CUZCO     HUAYOPATA      P.HUAYOPATA               2               3
# 290  CUZCO      ECHARATE       P.ECHARATE               5               6
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               149             1461             1436             2897
# 5               107              172              126              298
# ..              ...              ...              ...              ...
# 284              34               42               42               84
# 285               3               25               10               35
# 286              11               46               26               72
# 288               5               38               38               76
# 290              11               45               39               84
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3        867  ...                     1369                     2751
# 5         28  ...                      162                      399
# ..       ...  ...                      ...                      ...
# 284       17  ...                       60                      115
# 285        3  ...                       11                       38
# 286       22  ...                       31                       83
# 288       18  ...                       41                       81
# 290       30  ...                       45                       95
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           1532           1502            4             8    1461       544
# 5            241            164            0             0      24       252
# ..           ...            ...          ...           ...     ...       ...
# 284           55             63            0             0      37        31
# 285           27             11            0             0       0         0
# 286           52             31            0             0       0         0
# 288           40             41            0             0      81         0
# 290           50             45            0             0      53        42
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1038      3
# 5        129      0
# ..       ...    ...
# 284       50      0
# 285       38      0
# 286       83      0
# 288        0      0
# 290        0      0
#
# [238 rows x 41 columns]
#     Region      District            Place   4_6_years_men 4_6_years_women  \
# 0    CUZCO           NaN              NaN             NaN             NaN
# 1    CUZCO           NaN              NaN  De 4 a 6 años              NaN
# 2    CUZCO           NaN              NaN              v.              M.
# 3    CUZCO         CUZCO         P. CUZCO              75              74
# 5    CUZCO  SAN GERONIMO  P. SAN GERONIMO              69              38
# ..     ...           ...              ...             ...             ...
# 284  CUZCO    VILCABAMBA     P.VILCABAMBA              13              21
# 285  CUZCO    VILCABAMBA          C.LUCMA               2               1
# 286  CUZCO    VILCABAMBA          PUCYURA               6               5
# 288  CUZCO     HUAYOPATA      P.HUAYOPATA               2               3
# 290  CUZCO      ECHARATE       P.ECHARATE               5               6
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               149             1461             1436             2897
# 5               107              172              126              298
# ..              ...              ...              ...              ...
# 284              34               42               42               84
# 285               3               25               10               35
# 286              11               46               26               72
# 288               5               38               38               76
# 290              11               45               39               84
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3        867  ...                     1369                     2751
# 5         28  ...                      162                      399
# ..       ...  ...                      ...                      ...
# 284       17  ...                       60                      115
# 285        3  ...                       11                       38
# 286       22  ...                       31                       83
# 288       18  ...                       41                       81
# 290       30  ...                       45                       95
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           1532           1502            4             8    1461       544
# 5            241            164            0             0      24       252
# ..           ...            ...          ...           ...     ...       ...
# 284           55             63            0             0      37        31
# 285           27             11            0             0       0         0
# 286           52             31            0             0       0         0
# 288           40             41            0             0      81         0
# 290           50             45            0             0      53        42
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1038      3
# 5        129      0
# ..       ...    ...
# 284       50      0
# 285       38      0
# 286       83      0
# 288        0      0
# 290        0      0
#
# [238 rows x 41 columns]

# %%
cu_clean = cu_clean.drop([0, 1, 2],axis=0)
cu_clean
# Out:
#     Region       District             Place 4_6_years_men 4_6_years_women  \
# 3    CUZCO          CUZCO          P. CUZCO            75              74
# 5    CUZCO   SAN GERONIMO   P. SAN GERONIMO            69              38
# 6    CUZCO   SAN GERONIMO            SAILLA            14              18
# 8    CUZCO  SAN SEBASTIAN  P. SAN SEBASTIAN            10              13
# 10   CUZCO        YANAOCA        P. YANAOCA            25              19
# ..     ...            ...               ...           ...             ...
# 284  CUZCO     VILCABAMBA      P.VILCABAMBA            13              21
# 285  CUZCO     VILCABAMBA           C.LUCMA             2               1
# 286  CUZCO     VILCABAMBA           PUCYURA             6               5
# 288  CUZCO      HUAYOPATA       P.HUAYOPATA             2               3
# 290  CUZCO       ECHARATE        P.ECHARATE             5               6
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               149           1461             1436             2897      867
# 5               107            172              126              298       28
# 6                32             58               34               92       26
# 8                23            172               71              243       89
# 10               44            100               75              175       28
# ..              ...            ...              ...              ...      ...
# 284              34             42               42               84       17
# 285               3             25               10               35        3
# 286              11             46               26               72       22
# 288               5             38               38               76       18
# 290              11             45               39               84       30
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                     1369                     2751         1532
# 5    ...                      162                      399          241
# 6    ...                       52                      124           72
# 8    ...                       81                      259          182
# 10   ...                       94                      218          125
# ..   ...                      ...                      ...          ...
# 284  ...                       60                      115           55
# 285  ...                       11                       38           27
# 286  ...                       31                       83           52
# 288  ...                       41                       81           40
# 290  ...                       45                       95           50
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3             1502           4             8   1461     544     1038      3
# 5              164           0             0     24     252      129      0
# 6               52           0             0     11     113        0      0
# 8               81           0             3     37     229        0      0
# 10              94           0             0     71     140        6      2
# ..             ...         ...           ...    ...     ...      ...    ...
# 284             63           0             0     37      31       50      0
# 285             11           0             0      0       0       38      0
# 286             31           0             0      0       0       83      0
# 288             41           0             0     81       0        0      0
# 290             45           0             0     53      42        0      0
#
# [235 rows x 41 columns]
#     Region       District             Place 4_6_years_men 4_6_years_women  \
# 3    CUZCO          CUZCO          P. CUZCO            75              74
# 5    CUZCO   SAN GERONIMO   P. SAN GERONIMO            69              38
# 6    CUZCO   SAN GERONIMO            SAILLA            14              18
# 8    CUZCO  SAN SEBASTIAN  P. SAN SEBASTIAN            10              13
# 10   CUZCO        YANAOCA        P. YANAOCA            25              19
# ..     ...            ...               ...           ...             ...
# 284  CUZCO     VILCABAMBA      P.VILCABAMBA            13              21
# 285  CUZCO     VILCABAMBA           C.LUCMA             2               1
# 286  CUZCO     VILCABAMBA           PUCYURA             6               5
# 288  CUZCO      HUAYOPATA       P.HUAYOPATA             2               3
# 290  CUZCO       ECHARATE        P.ECHARATE             5               6
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               149           1461             1436             2897      867
# 5               107            172              126              298       28
# 6                32             58               34               92       26
# 8                23            172               71              243       89
# 10               44            100               75              175       28
# ..              ...            ...              ...              ...      ...
# 284              34             42               42               84       17
# 285               3             25               10               35        3
# 286              11             46               26               72       22
# 288               5             38               38               76       18
# 290              11             45               39               84       30
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                     1369                     2751         1532
# 5    ...                      162                      399          241
# 6    ...                       52                      124           72
# 8    ...                       81                      259          182
# 10   ...                       94                      218          125
# ..   ...                      ...                      ...          ...
# 284  ...                       60                      115           55
# 285  ...                       11                       38           27
# 286  ...                       31                       83           52
# 288  ...                       41                       81           40
# 290  ...                       45                       95           50
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3             1502           4             8   1461     544     1038      3
# 5              164           0             0     24     252      129      0
# 6               52           0             0     11     113        0      0
# 8               81           0             3     37     229        0      0
# 10              94           0             0     71     140        6      2
# ..             ...         ...           ...    ...     ...      ...    ...
# 284             63           0             0     37      31       50      0
# 285             11           0             0      0       0       38      0
# 286             31           0             0      0       0       83      0
# 288             41           0             0     81       0        0      0
# 290             45           0             0     53      42        0      0
#
# [235 rows x 41 columns]

# %%
cu_clean = cu_clean.reset_index()
cu_clean
# Out:
#      index Region       District             Place 4_6_years_men  \
# 0        3  CUZCO          CUZCO          P. CUZCO            75
# 1        5  CUZCO   SAN GERONIMO   P. SAN GERONIMO            69
# 2        6  CUZCO   SAN GERONIMO            SAILLA            14
# 3        8  CUZCO  SAN SEBASTIAN  P. SAN SEBASTIAN            10
# 4       10  CUZCO        YANAOCA        P. YANAOCA            25
# ..     ...    ...            ...               ...           ...
# 230    284  CUZCO     VILCABAMBA      P.VILCABAMBA            13
# 231    285  CUZCO     VILCABAMBA           C.LUCMA             2
# 232    286  CUZCO     VILCABAMBA           PUCYURA             6
# 233    288  CUZCO      HUAYOPATA       P.HUAYOPATA             2
# 234    290  CUZCO       ECHARATE        P.ECHARATE             5
#
#     4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0                74             149           1461             1436
# 1                38             107            172              126
# 2                18              32             58               34
# 3                13              23            172               71
# 4                19              44            100               75
# ..              ...             ...            ...              ...
# 230              21              34             42               42
# 231               1               3             25               10
# 232               5              11             46               26
# 233               3               5             38               38
# 234               6              11             45               39
#
#     6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0               2897  ...                     1369                     2751
# 1                298  ...                      162                      399
# 2                 92  ...                       52                      124
# 3                243  ...                       81                      259
# 4                175  ...                       94                      218
# ..               ...  ...                      ...                      ...
# 230               84  ...                       60                      115
# 231               35  ...                       11                       38
# 232               72  ...                       31                       83
# 233               76  ...                       41                       81
# 234               84  ...                       45                       95
#
#     peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0           1532           1502           4             8   1461     544
# 1            241            164           0             0     24     252
# 2             72             52           0             0     11     113
# 3            182             81           0             3     37     229
# 4            125             94           0             0     71     140
# ..           ...            ...         ...           ...    ...     ...
# 230           55             63           0             0     37      31
# 231           27             11           0             0      0       0
# 232           52             31           0             0      0       0
# 233           40             41           0             0     81       0
# 234           50             45           0             0     53      42
#
#     mestizos blacks
# 0       1038      3
# 1        129      0
# 2          0      0
# 3          0      0
# 4          6      2
# ..       ...    ...
# 230       50      0
# 231       38      0
# 232       83      0
# 233        0      0
# 234        0      0
#
# [235 rows x 42 columns]
#      index Region       District             Place 4_6_years_men  \
# 0        3  CUZCO          CUZCO          P. CUZCO            75
# 1        5  CUZCO   SAN GERONIMO   P. SAN GERONIMO            69
# 2        6  CUZCO   SAN GERONIMO            SAILLA            14
# 3        8  CUZCO  SAN SEBASTIAN  P. SAN SEBASTIAN            10
# 4       10  CUZCO        YANAOCA        P. YANAOCA            25
# ..     ...    ...            ...               ...           ...
# 230    284  CUZCO     VILCABAMBA      P.VILCABAMBA            13
# 231    285  CUZCO     VILCABAMBA           C.LUCMA             2
# 232    286  CUZCO     VILCABAMBA           PUCYURA             6
# 233    288  CUZCO      HUAYOPATA       P.HUAYOPATA             2
# 234    290  CUZCO       ECHARATE        P.ECHARATE             5
#
#     4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0                74             149           1461             1436
# 1                38             107            172              126
# 2                18              32             58               34
# 3                13              23            172               71
# 4                19              44            100               75
# ..              ...             ...            ...              ...
# 230              21              34             42               42
# 231               1               3             25               10
# 232               5              11             46               26
# 233               3               5             38               38
# 234               6              11             45               39
#
#     6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0               2897  ...                     1369                     2751
# 1                298  ...                      162                      399
# 2                 92  ...                       52                      124
# 3                243  ...                       81                      259
# 4                175  ...                       94                      218
# ..               ...  ...                      ...                      ...
# 230               84  ...                       60                      115
# 231               35  ...                       11                       38
# 232               72  ...                       31                       83
# 233               76  ...                       41                       81
# 234               84  ...                       45                       95
#
#     peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0           1532           1502           4             8   1461     544
# 1            241            164           0             0     24     252
# 2             72             52           0             0     11     113
# 3            182             81           0             3     37     229
# 4            125             94           0             0     71     140
# ..           ...            ...         ...           ...    ...     ...
# 230           55             63           0             0     37      31
# 231           27             11           0             0      0       0
# 232           52             31           0             0      0       0
# 233           40             41           0             0     81       0
# 234           50             45           0             0     53      42
#
#     mestizos blacks
# 0       1038      3
# 1        129      0
# 2          0      0
# 3          0      0
# 4          6      2
# ..       ...    ...
# 230       50      0
# 231       38      0
# 232       83      0
# 233        0      0
# 234        0      0
#
# [235 rows x 42 columns]

# %%
a = cu_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object

# %%
Code1= a12.to_excel("Region_Cuzco.xlsx")
Code1
