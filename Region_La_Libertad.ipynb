# %%
 import pandas as pd

# %% [markdown]
# # Import data

# %%
libertad = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/La_Libertad.xlsx")
libertad["Region"] = "LA LIBERTAD"
region = libertad["Region"]
libertad.drop(labels = "Region", axis=1, inplace = True)
libertad.insert(0, "Region", region)
libertad.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %% [markdown]
# # Clean String Variables

# %%
# Translate to Uppercase variables 
libertad["District"] =libertad["District"].str.upper()
libertad["Place"] = libertad["Place"].str.upper()
libertad["Place"] = libertad["Place"].str.strip()

# %%
# Find errors with string = Total
errors =libertad.loc[libertad["Place"]=="TOTAL"]
error_list = errors.index.tolist()

libertad_clean = libertad.drop(libertad.index[error_list])
libertad_clean
# Out:
#           Region    District         Place   4_6_years_men 4_6_years_women  \
# 0    LA LIBERTAD         NaN           NaN             NaN             NaN
# 1    LA LIBERTAD         NaN           NaN  De 4 a 6 años              NaN
# 2    LA LIBERTAD         NaN           NaN              v.              M.
# 3    LA LIBERTAD    TRUJILLO    P.TRUJILLO             162             136
# 4    LA LIBERTAD    TRUJILLO      C.LAREDO              17              14
# ..           ...         ...           ...             ...             ...
# 244  LA LIBERTAD  CACHICADAN      HOSPITAL               0               0
# 245  LA LIBERTAD  CACHICADAN       C.CHUCA               0               0
# 247  LA LIBERTAD   MOLLEPATA   P.MOLLETAPA              17               4
# 248  LA LIBERTAD   MOLLEPATA  C.MOLLEBAMBA               8               2
# 250  LA LIBERTAD   SITABAMBA   P.SITABAMBA              29              27
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               298              823              809             1632
# 4                31               83               68              151
# ..              ...              ...              ...              ...
# 244               0               13                8               21
# 245               0              113              100              213
# 247              21              204               56              260
# 248              10               67               28               95
# 250              56              135               83              218
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3        580  ...                      845                     1743
# 4         53  ...                       80                      178
# ..       ...  ...                      ...                      ...
# 244        0  ...                        8                       21
# 245       73  ...                      100                      213
# 247       17  ...                       60                      281
# 248       15  ...                       30                      105
# 250       63  ...                      110                      274
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3            985            945            0             0     503        66
# 4            100             82            0             0      31        61
# ..           ...            ...          ...           ...     ...       ...
# 244           13              8            0             0       0         0
# 245          113            100            0             0      15         8
# 247          221             60            0             0       0         0
# 248           75             30            0             0       8        88
# 250          164            110            0             0       0         0
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1294     67
# 4         88      2
# ..       ...    ...
# 244       21      0
# 245      190      0
# 247      281      0
# 248        9      0
# 250      274      0
#
# [202 rows x 41 columns]

# %%
# Drop first 3 rows beacuse it does not serve us
libertad_clean = libertad_clean.drop([0, 1, 2],axis=0)
libertad_clean
# Out:
#           Region    District          Place 4_6_years_men 4_6_years_women  \
# 3    LA LIBERTAD    TRUJILLO     P.TRUJILLO           162             136
# 4    LA LIBERTAD    TRUJILLO       C.LAREDO            17              14
# 5    LA LIBERTAD    TRUJILLO  LAS HACIENDAS             6              10
# 6    LA LIBERTAD    TRUJILLO        MAMICHE             3              11
# 8    LA LIBERTAD      ASCOPE       P.ASCOPE            75              68
# ..           ...         ...            ...           ...             ...
# 244  LA LIBERTAD  CACHICADAN       HOSPITAL             0               0
# 245  LA LIBERTAD  CACHICADAN        C.CHUCA             0               0
# 247  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA            17               4
# 248  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA             8               2
# 250  LA LIBERTAD   SITABAMBA    P.SITABAMBA            29              27
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               298            823              809             1632      580
# 4                31             83               68              151       53
# 5                16             44               40               84        5
# 6                14             27               22               49       22
# 8               143            331              321              652      176
# ..              ...            ...              ...              ...      ...
# 244               0             13                8               21        0
# 245               0            113              100              213       73
# 247              21            204               56              260       17
# 248              10             67               28               95       15
# 250              56            135               83              218       63
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                      845                     1743          985
# 4    ...                       80                      178          100
# 5    ...                       50                      100           50
# 6    ...                       33                       63           30
# 8    ...                      336                      696          406
# ..   ...                      ...                      ...          ...
# 244  ...                        8                       21           13
# 245  ...                      100                      213          113
# 247  ...                       60                      281          221
# 248  ...                       30                      105           75
# 250  ...                      110                      274          164
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3              945           0             0    503      66     1294     67
# 4               82           0             0     31      61       88      2
# 5               50           0             0      5      22       61     12
# 6               33           0             0      0      56        7      0
# 8              389           0             0    217      55      517      6
# ..             ...         ...           ...    ...     ...      ...    ...
# 244              8           0             0      0       0       21      0
# 245            100           0             0     15       8      190      0
# 247             60           0             0      0       0      281      0
# 248             30           0             0      8      88        9      0
# 250            110           0             0      0       0      274      0
#
# [199 rows x 41 columns]

# %%
# drop by index
# Reset to index because we have removed rows and renumbering them
libertad_clean = libertad_clean.reset_index()
libertad_clean
# Out:
#      index       Region    District          Place 4_6_years_men  \
# 0        3  LA LIBERTAD    TRUJILLO     P.TRUJILLO           162
# 1        4  LA LIBERTAD    TRUJILLO       C.LAREDO            17
# 2        5  LA LIBERTAD    TRUJILLO  LAS HACIENDAS             6
# 3        6  LA LIBERTAD    TRUJILLO        MAMICHE             3
# 4        8  LA LIBERTAD      ASCOPE       P.ASCOPE            75
# ..     ...          ...         ...            ...           ...
# 194    244  LA LIBERTAD  CACHICADAN       HOSPITAL             0
# 195    245  LA LIBERTAD  CACHICADAN        C.CHUCA             0
# 196    247  LA LIBERTAD   MOLLEPATA    P.MOLLETAPA            17
# 197    248  LA LIBERTAD   MOLLEPATA   C.MOLLEBAMBA             8
# 198    250  LA LIBERTAD   SITABAMBA    P.SITABAMBA            29
#
#     4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0               136             298            823              809
# 1                14              31             83               68
# 2                10              16             44               40
# 3                11              14             27               22
# 4                68             143            331              321
# ..              ...             ...            ...              ...
# 194               0               0             13                8
# 195               0               0            113              100
# 196               4              21            204               56
# 197               2              10             67               28
# 198              27              56            135               83
#
#     6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0               1632  ...                      845                     1743
# 1                151  ...                       80                      178
# 2                 84  ...                       50                      100
# 3                 49  ...                       33                       63
# 4                652  ...                      336                      696
# ..               ...  ...                      ...                      ...
# 194               21  ...                        8                       21
# 195              213  ...                      100                      213
# 196              260  ...                       60                      281
# 197               95  ...                       30                      105
# 198              218  ...                      110                      274
#
#     peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0            985            945           0             0    503      66
# 1            100             82           0             0     31      61
# 2             50             50           0             0      5      22
# 3             30             33           0             0      0      56
# 4            406            389           0             0    217      55
# ..           ...            ...         ...           ...    ...     ...
# 194           13              8           0             0      0       0
# 195          113            100           0             0     15       8
# 196          221             60           0             0      0       0
# 197           75             30           0             0      8      88
# 198          164            110           0             0      0       0
#
#     mestizos blacks
# 0       1294     67
# 1         88      2
# 2         61     12
# 3          7      0
# 4        517      6
# ..       ...    ...
# 194       21      0
# 195      190      0
# 196      281      0
# 197        9      0
# 198      274      0
#
# [199 rows x 42 columns]

# %%
a = libertad_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a12= a.men_not_write.fillna(0)
a12 = a.men_not_write.astype(int)

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object
