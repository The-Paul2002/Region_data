# %%
import pandas as pd

# %%
lambayeque = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/Lambayeque.xlsx")
lambayeque["Region"] = "LAMBAYEQUE"
Region = lambayeque["Region"]
lambayeque.drop(labels = "Region", axis=1, inplace = True)
lambayeque.insert(0, "Region", Region)
lambayeque.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
lambayeque["District"] =lambayeque["District"].str.upper()
lambayeque["Place"] = lambayeque["Place"].str.upper()

# %%
lambayeque["Place"] = lambayeque["Place"].str.strip()
# Find errors with string = Total
errors = lambayeque.loc[lambayeque["Place"]=="TOTAL"]
error_list = errors.index.tolist()

l_clean = lambayeque.drop(lambayeque.index[error_list])
l_clean
# Out:
#         Region     District           Place   4_6_years_men 4_6_years_women  \
# 0   LAMBAYEQUE          NaN             NaN             NaN             NaN
# 1   LAMBAYEQUE          NaN             NaN  De 4 a 6 años              NaN
# 2   LAMBAYEQUE          NaN             NaN              v.              M.
# 3   LAMBAYEQUE   LAMBAYEQUE      LAMBAYEQUE              51              61
# 5   LAMBAYEQUE    FERREÑAFE       FERREÑAFE             177             122
# 7   LAMBAYEQUE      MOCHUMI         MOCHUMI               8              17
# 9   LAMBAYEQUE       PACORA          PACORA              19              16
# 11  LAMBAYEQUE      JAYANCA         JAYANCA              20              24
# 13  LAMBAYEQUE       MOTUPE          MOTUPE              58              45
# 14  LAMBAYEQUE       MOTUPE     P. CHÓCHOPE              14               5
# 15  LAMBAYEQUE       MOTUPE         ARROSAL               1               0
# ...

# %%
l_clean= l_clean.drop([0, 1, 2],axis=0)
l_clean
# Out:
#         Region     District           Place 4_6_years_men 4_6_years_women  \
# 3   LAMBAYEQUE   LAMBAYEQUE      LAMBAYEQUE            51              61
# 5   LAMBAYEQUE    FERREÑAFE       FERREÑAFE           177             122
# 7   LAMBAYEQUE      MOCHUMI         MOCHUMI             8              17
# 9   LAMBAYEQUE       PACORA          PACORA            19              16
# 11  LAMBAYEQUE      JAYANCA         JAYANCA            20              24
# 13  LAMBAYEQUE       MOTUPE          MOTUPE            58              45
# 14  LAMBAYEQUE       MOTUPE     P. CHÓCHOPE            14               5
# 15  LAMBAYEQUE       MOTUPE         ARROSAL             1               0
# 17  LAMBAYEQUE        OLMOS           OLMOS            48              30
# 19  LAMBAYEQUE      MÓRROPE         MÓRROPE            28              25
# 21  LAMBAYEQUE       TÚCUME          TÚCUME            27              20
# 22  LAMBAYEQUE       TÚCUME       C. ILLINO            14              15
# ...

# %%
l_clean = l_clean.reset_index()
l_clean
# Out:
#     index      Region     District           Place 4_6_years_men  \
# 0       3  LAMBAYEQUE   LAMBAYEQUE      LAMBAYEQUE            51
# 1       5  LAMBAYEQUE    FERREÑAFE       FERREÑAFE           177
# 2       7  LAMBAYEQUE      MOCHUMI         MOCHUMI             8
# 3       9  LAMBAYEQUE       PACORA          PACORA            19
# 4      11  LAMBAYEQUE      JAYANCA         JAYANCA            20
# 5      13  LAMBAYEQUE       MOTUPE          MOTUPE            58
# 6      14  LAMBAYEQUE       MOTUPE     P. CHÓCHOPE            14
# 7      15  LAMBAYEQUE       MOTUPE         ARROSAL             1
# 8      17  LAMBAYEQUE        OLMOS           OLMOS            48
# 9      19  LAMBAYEQUE      MÓRROPE         MÓRROPE            28
# 10     21  LAMBAYEQUE       TÚCUME          TÚCUME            27
# 11     22  LAMBAYEQUE       TÚCUME       C. ILLINO            14
# 12     24  LAMBAYEQUE        SALAS        P. SALAS             6
# ...

# %%
a= l_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a= a.infer_objects()
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
Code1= a.to_excel("Region_Lambayeque.xlsx") 
Code1
