# %%
import pandas as pd

# %%
ar = pd.read_excel(r"C:\Users\egonz\Desktop\Data/AREQUIPA (1).xlsx")

# %%
ar["Region"] = "AREQUIPA"
region = ar["Region"]
ar.drop(labels = "Region", axis=1, inplace = True)
ar.insert(0, "Region", region)

# %%
ar.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
ar
# Out:
#        Region    District        Place   4_6_years_men 4_6_years_women  \
# 0    AREQUIPA         NaN          NaN             NaN             NaN
# 1    AREQUIPA         NaN          NaN  De 4 a 6 años              NaN
# 2    AREQUIPA         NaN          NaN              v.              M.
# 3    AREQUIPA    AREQUIPA  P. Arequipa             407             396
# 4    AREQUIPA    AREQUIPA        TOTAL               0               0
# ..        ...         ...          ...             ...             ...
# 265  AREQUIPA  HUANUHUANU        TOTAL               0               0
# 266  AREQUIPA    ATIQUIPA  P. Atiquipa               5               1
# 267  AREQUIPA    ATIQUIPA        TOTAL               0               0
# 268  AREQUIPA       ATICO     P. Atico               6               4
# 269  AREQUIPA       ATICO        TOTAL               0               0
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               803             2395             2306             4701
# 4                 0                0                0                0
# ..              ...              ...              ...              ...
# 265               0                0                0                0
# 266               6               20               13               33
# 267               0                0                0                0
# 268              10               46               10               56
# 269               0                0                0                0
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3       1372  ...                     2406                     4882
# 4          0  ...                        0                        0
# ..       ...  ...                      ...                      ...
# 265        0  ...                        0                        0
# 266        0  ...                       14                       39
# 267        0  ...                        0                        0
# 268        0  ...                       14                       66
# 269        0  ...                        0                        0
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           2793           1689            9            13    2153      1996
# 4              0              0            0             0       0         0
# ..           ...            ...          ...           ...     ...       ...
# 265            0              0            0             0       0         0
# 266           25             14            0             0      12         0
# 267            0              0            0             0       0         0
# 268           52             14            0             0      40         0
# 269            0              0            0             0       0         0
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1176    179
# 4          0      0
# ..       ...    ...
# 265        0      0
# 266       27      0
# 267        0      0
# 268       26      0
# 269        0      0
#
# [270 rows x 41 columns]

# %%
ar["District"] = ar["District"].str.upper()
ar["Place"] = ar["Place"].str.upper()

# %%
ar["Place"] = ar["Place"].str.strip()

# %%
errors = ar.loc[ar["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
ar_clean = ar.drop(ar.index[errors_list])
ar_clean
# Out:
#        Region    District          Place   4_6_years_men 4_6_years_women  \
# 0    AREQUIPA         NaN            NaN             NaN             NaN
# 1    AREQUIPA         NaN            NaN  De 4 a 6 años              NaN
# 2    AREQUIPA         NaN            NaN              v.              M.
# 3    AREQUIPA    AREQUIPA    P. AREQUIPA             407             396
# 5    AREQUIPA  MIRAFLORES  P. MIRAFLORES              60              60
# ..        ...         ...            ...             ...             ...
# 261  AREQUIPA       YAUCA       P. TAUCA               5               3
# 262  AREQUIPA       YAUCA          YAUCA               3               0
# 264  AREQUIPA  HUANUHUANU  P. HUANUHUANU               2               1
# 266  AREQUIPA    ATIQUIPA    P. ATIQUIPA               5               1
# 268  AREQUIPA       ATICO       P. ATICO               6               4
#
#     4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN  De 6 a 14 años               NaN              NaN
# 2                T.               V.               M.               T.
# 3               803             2395             2306             4701
# 5               120              336              287              623
# ..              ...              ...              ...              ...
# 261               8               21               19               40
# 262               3               22               12               34
# 264               3               23               24               47
# 266               6               20               13               33
# 268              10               46               10               56
#
#     man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0        NaN  ...                      NaN                      NaN
# 1        NaN  ...                      NaN                      NaN
# 2         v.  ...                       M.                       T.
# 3       1372  ...                     2406                     4882
# 5        109  ...                      345                      735
# ..       ...  ...                      ...                      ...
# 261       16  ...                       22                       48
# 262       13  ...                       12                       37
# 264        5  ...                       25                       50
# 266        0  ...                       14                       39
# 268        0  ...                       14                       66
#
#     peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0            NaN            NaN          NaN           NaN     NaN       NaN
# 1      Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2             V.            M.            V.            M.  Blanca  Indígena
# 3           2793           1689            9            13    2153      1996
# 5            396            347            0             0     282       208
# ..           ...            ...          ...           ...     ...       ...
# 261           26             22            0             0      16         3
# 262           25             12            0             0      12         0
# 264           25             25            0             0       6         0
# 266           25             14            0             0      12         0
# 268           52             14            0             0      40         0
#
#     mestizos blacks
# 0        NaN    NaN
# 1        NaN    NaN
# 2    Mestiza  Negra
# 3       1176    179
# 5        253      0
# ..       ...    ...
# 261       29      0
# 262       25      0
# 264       44      0
# 266       27      0
# 268       26      0
#
# [203 rows x 41 columns]

# %%
ar_clean = ar_clean.drop([0, 1, 2],axis=0)
ar_clean
# Out:
#        Region    District          Place 4_6_years_men 4_6_years_women  \
# 3    AREQUIPA    AREQUIPA    P. AREQUIPA           407             396
# 5    AREQUIPA  MIRAFLORES  P. MIRAFLORES            60              60
# 6    AREQUIPA  MIRAFLORES     LAMBRAMANI             7               3
# 7    AREQUIPA  MIRAFLORES        CHILINA             2               3
# 9    AREQUIPA    CHIGUATA    P. CHIGUATA            50              56
# ..        ...         ...            ...           ...             ...
# 261  AREQUIPA       YAUCA       P. TAUCA             5               3
# 262  AREQUIPA       YAUCA          YAUCA             3               0
# 264  AREQUIPA  HUANUHUANU  P. HUANUHUANU             2               1
# 266  AREQUIPA    ATIQUIPA    P. ATIQUIPA             5               1
# 268  AREQUIPA       ATICO       P. ATICO             6               4
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               803           2395             2306             4701     1372
# 5               120            336              287              623      109
# 6                10             26               17               43       16
# 7                 5              9                9               18        4
# 9               106            225              176              401       35
# ..              ...            ...              ...              ...      ...
# 261               8             21               19               40       16
# 262               3             22               12               34       13
# 264               3             23               24               47        5
# 266               6             20               13               33        0
# 268              10             46               10               56        0
#
#      ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3    ...                     2406                     4882         2793
# 5    ...                      345                      735          396
# 6    ...                       20                       53           33
# 7    ...                       12                       23           11
# 9    ...                      232                      506          275
# ..   ...                      ...                      ...          ...
# 261  ...                       22                       48           26
# 262  ...                       12                       37           25
# 264  ...                       25                       50           25
# 266  ...                       14                       39           25
# 268  ...                       14                       66           52
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3             1689           9            13   2153    1996     1176    179
# 5              347           0             0    282     208      253      0
# 6               20           0             0     41       2       10      0
# 7               12           0             0      0       0       23      0
# 9              232           0             0     34     268      205      0
# ..             ...         ...           ...    ...     ...      ...    ...
# 261             22           0             0     16       3       29      0
# 262             12           0             0     12       0       25      0
# 264             25           0             0      6       0       44      0
# 266             14           0             0     12       0       27      0
# 268             14           0             0     40       0       26      0
#
# [200 rows x 41 columns]

# %%
ar_clean = ar_clean.reset_index()
ar_clean
# Out:
#      index    Region    District          Place 4_6_years_men 4_6_years_women  \
# 0        3  AREQUIPA    AREQUIPA    P. AREQUIPA           407             396
# 1        5  AREQUIPA  MIRAFLORES  P. MIRAFLORES            60              60
# 2        6  AREQUIPA  MIRAFLORES     LAMBRAMANI             7               3
# 3        7  AREQUIPA  MIRAFLORES        CHILINA             2               3
# 4        9  AREQUIPA    CHIGUATA    P. CHIGUATA            50              56
# ..     ...       ...         ...            ...           ...             ...
# 195    261  AREQUIPA       YAUCA       P. TAUCA             5               3
# 196    262  AREQUIPA       YAUCA          YAUCA             3               0
# 197    264  AREQUIPA  HUANUHUANU  P. HUANUHUANU             2               1
# 198    266  AREQUIPA    ATIQUIPA    P. ATIQUIPA             5               1
# 199    268  AREQUIPA       ATICO       P. ATICO             6               4
#
#     4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total  ...  \
# 0               803           2395             2306             4701  ...
# 1               120            336              287              623  ...
# 2                10             26               17               43  ...
# 3                 5              9                9               18  ...
# 4               106            225              176              401  ...
# ..              ...            ...              ...              ...  ...
# 195               8             21               19               40  ...
# 196               3             22               12               34  ...
# 197               3             23               24               47  ...
# 198               6             20               13               33  ...
# 199              10             46               10               56  ...
#
#     not_finished_instr_women not_finished_instr_total peruvian_men  \
# 0                       2406                     4882         2793
# 1                        345                      735          396
# 2                         20                       53           33
# 3                         12                       23           11
# 4                        232                      506          275
# ..                       ...                      ...          ...
# 195                       22                       48           26
# 196                       12                       37           25
# 197                       25                       50           25
# 198                       14                       39           25
# 199                       14                       66           52
#
#     peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 0             1689           9            13   2153    1996     1176    179
# 1              347           0             0    282     208      253      0
# 2               20           0             0     41       2       10      0
# 3               12           0             0      0       0       23      0
# 4              232           0             0     34     268      205      0
# ..             ...         ...           ...    ...     ...      ...    ...
# 195             22           0             0     16       3       29      0
# 196             12           0             0     12       0       25      0
# 197             25           0             0      6       0       44      0
# 198             14           0             0     12       0       27      0
# 199             14           0             0     40       0       26      0
#
# [200 rows x 42 columns]

# %%
a = ar_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                       object
# District                     object
# Place                        object
# 4_6_years_men               float64
# 4_6_years_women             float64
# 4_6_years_total             float64
# 6_14_years_men              float64
# 6_14_years_women            float64
# 6_14_years_total            float64
# man_read                    float64
# women_read                  float64
# total_read                  float64
# men_not_read                float64
# women_not_read              float64
# total_not_read              float64
# man_write                   float64
# women_write                 float64
# total_write                 float64
# men_not_write               float64
# women_not_write             float64
# total_not_write             float64
# instruction_men             float64
# instruction_women           float64
# instruction_total           float64
# no_instruction_men          float64
# no_instruction_women        float64
# no_instruction_total        float64
# finished_instr_men          float64
# finished_instr_women        float64
# finished_instr_total        float64
# not_finished_instr_men      float64
# not_finished_instr_women    float64
# not_finished_instr_total    float64
# peruvian_men                float64
# peruvian_women              float64
# foreign_men                 float64
# foreign_women               float64
# whites                      float64
# natives                     float64
# mestizos                    float64
# blacks                      float64
# dtype: object

# %% [markdown]
# ## Contiene columnas combinadas EN LLUTA por eso los toma como float
