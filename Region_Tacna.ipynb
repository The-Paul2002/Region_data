# %%
import pandas as pd

# %%
tc= pd.read_excel(r"C:\Users\egonz\Dropbox\PC\Desktop\Data/TACNA.xlsx")
tc
# Out:
#     DISTRITOS               LUGARES          EDADES Unnamed: 3 Unnamed: 4  \
# 0         NaN                   NaN             NaN        NaN        NaN
# 1         NaN                   NaN  De 4 a 6 años         NaN        NaN
# 2         NaN                   NaN              v.         M.         T.
# 3        SAMA         P. Morro Sama               7          4         11
# 4        SAMA           Sama Grande              11         11         22
# 5        SAMA         C. Buenavista               5          4          9
# 6        SAMA              Tomasiri              12         11         23
# 7        SAMA             Las Jaras              12         10         22
# 8        SAMA              Cuilorca               2          1          3
# 9        SAMA                 TOTAL               0          0          0
# 10    LOCUMBA            P. Locumba              11          7         18
# 11    LOCUMBA              C. Sinti               4          1          5
# 12    LOCUMBA                 Chipe               5          4          9
# 13    LOCUMBA               Sagollo               4          1          5
# 14    LOCUMBA                 TOTAL               0          0          0
# 15    ILABAYA            P. Ilabaya               8          8         16
# 16    ILABAYA          C. Boroqueña               0          2          2
# 17    ILABAYA                Mirave               0          1          1
# 18    ILABAYA              Chululmi              13          7         20
# 19    ILABAYA               Cambaya               1          0          1
# 20    ILABAYA            Carumblaya               2          0          2
# 21    ILABAYA                 TOTAL               0          0          0
# 22  CANDARAVE          C. Candarave              25         19         44
# 23  CANDARAVE               Cairani              21         10         31
# 24  CANDARAVE         C, Quilahuani              22         17         39
# 25  CANDARAVE               Pallata              12          6         18
# 26  CANDARAVE                 TOTAL               0          0          0
# 27   CURIBAYA           P. Curibaya               7          2          9
# 28   CURIBAYA           A. Huanuara               8          6         14
# 29   CURIBAYA                 TOTAL               0          0          0
# 30     TICACO             P. Ticaco              13         23         36
# 31     TICACO           A. Susapaya               3          6          9
# 32     TICACO           Challahuaya               3          7         10
# 33     TICACO               C. Cano               2          3          5
# 34     TICACO            A. Yabroco               5          5         10
# 35     TICACO  Londaniza y Coropuro               3          3          6
# 36     TICACO  C. Tala y Chipispaya               3          1          4
# 37     TICACO                 TOTAL               0          0          0
#
#          Unnamed: 5 Unnamed: 6 Unnamed: 7 SABEN LEER  Unnamed: 9  ...  \
# 0               NaN        NaN        NaN         NaN        NaN  ...
# 1   De 6 a 14 años         NaN        NaN         NaN        NaN  ...
# 2                V.         M.         T.          v.         M.  ...
# 3                23         14         37           6          1  ...
# 4                56         52        108          23         18  ...
# 5                20         15         35           6          3  ...
# 6                38         20         58          13          7  ...
# 7                43         24         67          18         13  ...
# 8                 5         13         18           1          0  ...
# 9                 0          0          0           0          0  ...
# 10               80         63        143          41         35  ...
# 11               32         18         50          12          7  ...
# 12               15         12         27           2          2  ...
# 13               10         10         20           2          3  ...
# 14                0          0          0           0          0  ...
# 15               69         51        120          26         22  ...
# 16                7          8         15           0          0  ...
# 17               14          5         19           0          0  ...
# 18               26         24         50           4          1  ...
# 19               20         12         32           1          0  ...
# 20               14          8         22          10          0  ...
# 21                0          0          0           0          0  ...
# 22               99         69        168          41         32  ...
# 23               42         32         74           2          6  ...
# 24               28         32         60          15          0  ...
# 25               20         19         39           3          0  ...
# 26                0          0          0           0          0  ...
# 27               37         17         54           4          0  ...
# 28               29         17         46           0          0  ...
# 29                0          0          0           0          0  ...
# 30               37         55         92          28          9  ...
# 31               17         11         28           0          0  ...
# 32               10         14         24           4          0  ...
# 33               11          5         16           0          0  ...
# 34               18          7         25           0          0  ...
# 35                6          4         10           6          3  ...
# 36                7          7         14           0          0  ...
# 37                0          0          0           0          0  ...
#
#    Unnamed: 30 Unnamed: 31 NACIONALIDAD Unnamed: 33  Unnamed: 34 Unnamed: 35  \
# 0          NaN         NaN          NaN         NaN          NaN         NaN
# 1          NaN         NaN    Peruanos          NaN  Extranjeros         NaN
# 2           M.          T.           V.         M.            V.          M.
# 3           18          48           30          18            0           0
# 4           70         136           67          70            0           0
# 5           19          44           25          19            0           0
# 6           31          81           50          31            0           0
# 7           34          88           55          34            0           0
# 8           14          21            7          14            0           0
# 9            0           0            0           0            0           0
# 10          70         157           91          70            0           0
# 11          19          55           36          19            0           0
# 12          16          36           20          16            0           0
# 13          11          25           14          11            0           0
# 14           0           0            0           0            0           0
# 15          59         136           77          59            0           0
# 16          10          17            7          10            0           0
# 17           6          20           14           6            0           0
# 18          31          70           39          31            0           0
# 19          12          33           21          12            0           0
# 20           8          24           16           8            0           0
# 21           0           0            0           0            0           0
# 22          84         201          123          88            1           0
# 23          42         105           63          41            0           1
# 24          49          99           50          49            0           0
# 25          25          57           32          25            0           0
# 26           0           0            0           0            0           0
# 27          19          62           42          19            2           0
# 28          23          60           37          23            0           0
# 29           0           0            0           0            0           0
# 30          78         128           47          77            3           1
# 31          17          37           20          17            0           0
# 32          21          34           13          21            0           0
# 33           8          21           13           8            0           0
# 34          12          35           23          12            0           0
# 35           7          16            9           7            0           0
# 36           8          18           10           8            0           0
# 37           0           0            0           0            0           0
#
#      RAZAS Unnamed: 37 Unnamed: 38 Unnamed: 39
# 0      NaN         NaN         NaN         NaN
# 1      NaN         NaN         NaN         NaN
# 2   Blanca    Indígena     Mestiza       Negra
# 3       11          28           4           5
# 4      107          15          11           4
# 5       12          17           0          15
# 6       33          27          14           7
# 7        8          14          27          40
# 8        6           3           4           8
# 9        0           0           0           0
# 10      74          43           3          41
# 11      12          21           1          21
# 12      18          14           0           4
# 13       9          13           0           3
# 14       0           0           0           0
# 15      22         114           0           0
# 16       0          17           0           0
# 17       0          20           0           0
# 18       0          70           0           0
# 19       0          33           0           0
# 20       0          24           0           0
# 21       0           0           0           0
# 22      98          77          37           0
# 23       1          63          41           0
# 24      11          84           4           0
# 25       7          40          10           0
# 26       0           0           0           0
# 27       0           9          54           0
# 28       2          58           0           0
# 29       0           0           0           0
# 30      17         111           0           0
# 31       0          37           0           0
# 32       0          34           0           0
# 33       0          21           0           0
# 34       0          35           0           0
# 35       0          16           0           0
# 36       0          18           0           0
# 37       0           0           0           0
#
# [38 rows x 40 columns]

# %%
tc["Region"] = "MOQUEGUA"
region = tc["Region"]
tc.drop(labels = "Region", axis=1, inplace = True)
tc.insert(0, "Region", region)
tc
# Out:
#       Region  DISTRITOS               LUGARES          EDADES Unnamed: 3  \
# 0   MOQUEGUA        NaN                   NaN             NaN        NaN
# 1   MOQUEGUA        NaN                   NaN  De 4 a 6 años         NaN
# 2   MOQUEGUA        NaN                   NaN              v.         M.
# 3   MOQUEGUA       SAMA         P. Morro Sama               7          4
# 4   MOQUEGUA       SAMA           Sama Grande              11         11
# 5   MOQUEGUA       SAMA         C. Buenavista               5          4
# 6   MOQUEGUA       SAMA              Tomasiri              12         11
# 7   MOQUEGUA       SAMA             Las Jaras              12         10
# 8   MOQUEGUA       SAMA              Cuilorca               2          1
# 9   MOQUEGUA       SAMA                 TOTAL               0          0
# 10  MOQUEGUA    LOCUMBA            P. Locumba              11          7
# 11  MOQUEGUA    LOCUMBA              C. Sinti               4          1
# 12  MOQUEGUA    LOCUMBA                 Chipe               5          4
# 13  MOQUEGUA    LOCUMBA               Sagollo               4          1
# 14  MOQUEGUA    LOCUMBA                 TOTAL               0          0
# 15  MOQUEGUA    ILABAYA            P. Ilabaya               8          8
# 16  MOQUEGUA    ILABAYA          C. Boroqueña               0          2
# 17  MOQUEGUA    ILABAYA                Mirave               0          1
# 18  MOQUEGUA    ILABAYA              Chululmi              13          7
# 19  MOQUEGUA    ILABAYA               Cambaya               1          0
# 20  MOQUEGUA    ILABAYA            Carumblaya               2          0
# 21  MOQUEGUA    ILABAYA                 TOTAL               0          0
# 22  MOQUEGUA  CANDARAVE          C. Candarave              25         19
# 23  MOQUEGUA  CANDARAVE               Cairani              21         10
# 24  MOQUEGUA  CANDARAVE         C, Quilahuani              22         17
# 25  MOQUEGUA  CANDARAVE               Pallata              12          6
# 26  MOQUEGUA  CANDARAVE                 TOTAL               0          0
# 27  MOQUEGUA   CURIBAYA           P. Curibaya               7          2
# 28  MOQUEGUA   CURIBAYA           A. Huanuara               8          6
# 29  MOQUEGUA   CURIBAYA                 TOTAL               0          0
# 30  MOQUEGUA     TICACO             P. Ticaco              13         23
# 31  MOQUEGUA     TICACO           A. Susapaya               3          6
# 32  MOQUEGUA     TICACO           Challahuaya               3          7
# 33  MOQUEGUA     TICACO               C. Cano               2          3
# 34  MOQUEGUA     TICACO            A. Yabroco               5          5
# 35  MOQUEGUA     TICACO  Londaniza y Coropuro               3          3
# 36  MOQUEGUA     TICACO  C. Tala y Chipispaya               3          1
# 37  MOQUEGUA     TICACO                 TOTAL               0          0
#
#    Unnamed: 4       Unnamed: 5 Unnamed: 6 Unnamed: 7 SABEN LEER   ...  \
# 0         NaN              NaN        NaN        NaN         NaN  ...
# 1         NaN  De 6 a 14 años         NaN        NaN         NaN  ...
# 2          T.               V.         M.         T.          v.  ...
# 3          11               23         14         37           6  ...
# 4          22               56         52        108          23  ...
# 5           9               20         15         35           6  ...
# 6          23               38         20         58          13  ...
# 7          22               43         24         67          18  ...
# 8           3                5         13         18           1  ...
# 9           0                0          0          0           0  ...
# 10         18               80         63        143          41  ...
# 11          5               32         18         50          12  ...
# 12          9               15         12         27           2  ...
# 13          5               10         10         20           2  ...
# 14          0                0          0          0           0  ...
# 15         16               69         51        120          26  ...
# 16          2                7          8         15           0  ...
# 17          1               14          5         19           0  ...
# 18         20               26         24         50           4  ...
# 19          1               20         12         32           1  ...
# 20          2               14          8         22          10  ...
# 21          0                0          0          0           0  ...
# 22         44               99         69        168          41  ...
# 23         31               42         32         74           2  ...
# 24         39               28         32         60          15  ...
# 25         18               20         19         39           3  ...
# 26          0                0          0          0           0  ...
# 27          9               37         17         54           4  ...
# 28         14               29         17         46           0  ...
# 29          0                0          0          0           0  ...
# 30         36               37         55         92          28  ...
# 31          9               17         11         28           0  ...
# 32         10               10         14         24           4  ...
# 33          5               11          5         16           0  ...
# 34         10               18          7         25           0  ...
# 35          6                6          4         10           6  ...
# 36          4                7          7         14           0  ...
# 37          0                0          0          0           0  ...
#
#    Unnamed: 30 Unnamed: 31 NACIONALIDAD Unnamed: 33  Unnamed: 34 Unnamed: 35  \
# 0          NaN         NaN          NaN         NaN          NaN         NaN
# 1          NaN         NaN    Peruanos          NaN  Extranjeros         NaN
# 2           M.          T.           V.         M.            V.          M.
# 3           18          48           30          18            0           0
# 4           70         136           67          70            0           0
# 5           19          44           25          19            0           0
# 6           31          81           50          31            0           0
# 7           34          88           55          34            0           0
# 8           14          21            7          14            0           0
# 9            0           0            0           0            0           0
# 10          70         157           91          70            0           0
# 11          19          55           36          19            0           0
# 12          16          36           20          16            0           0
# 13          11          25           14          11            0           0
# 14           0           0            0           0            0           0
# 15          59         136           77          59            0           0
# 16          10          17            7          10            0           0
# 17           6          20           14           6            0           0
# 18          31          70           39          31            0           0
# 19          12          33           21          12            0           0
# 20           8          24           16           8            0           0
# 21           0           0            0           0            0           0
# 22          84         201          123          88            1           0
# 23          42         105           63          41            0           1
# 24          49          99           50          49            0           0
# 25          25          57           32          25            0           0
# 26           0           0            0           0            0           0
# 27          19          62           42          19            2           0
# 28          23          60           37          23            0           0
# 29           0           0            0           0            0           0
# 30          78         128           47          77            3           1
# 31          17          37           20          17            0           0
# 32          21          34           13          21            0           0
# 33           8          21           13           8            0           0
# 34          12          35           23          12            0           0
# 35           7          16            9           7            0           0
# 36           8          18           10           8            0           0
# 37           0           0            0           0            0           0
#
#      RAZAS Unnamed: 37 Unnamed: 38 Unnamed: 39
# 0      NaN         NaN         NaN         NaN
# 1      NaN         NaN         NaN         NaN
# 2   Blanca    Indígena     Mestiza       Negra
# 3       11          28           4           5
# 4      107          15          11           4
# 5       12          17           0          15
# 6       33          27          14           7
# 7        8          14          27          40
# 8        6           3           4           8
# 9        0           0           0           0
# 10      74          43           3          41
# 11      12          21           1          21
# 12      18          14           0           4
# 13       9          13           0           3
# 14       0           0           0           0
# 15      22         114           0           0
# 16       0          17           0           0
# 17       0          20           0           0
# 18       0          70           0           0
# 19       0          33           0           0
# 20       0          24           0           0
# 21       0           0           0           0
# 22      98          77          37           0
# 23       1          63          41           0
# 24      11          84           4           0
# 25       7          40          10           0
# 26       0           0           0           0
# 27       0           9          54           0
# 28       2          58           0           0
# 29       0           0           0           0
# 30      17         111           0           0
# 31       0          37           0           0
# 32       0          34           0           0
# 33       0          21           0           0
# 34       0          35           0           0
# 35       0          16           0           0
# 36       0          18           0           0
# 37       0           0           0           0
#
# [38 rows x 41 columns]

# %%
tc.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
tc
# Out:
#       Region   District                 Place   4_6_years_men 4_6_years_women  \
# 0   MOQUEGUA        NaN                   NaN             NaN             NaN
# 1   MOQUEGUA        NaN                   NaN  De 4 a 6 años              NaN
# 2   MOQUEGUA        NaN                   NaN              v.              M.
# 3   MOQUEGUA       SAMA         P. Morro Sama               7               4
# 4   MOQUEGUA       SAMA           Sama Grande              11              11
# 5   MOQUEGUA       SAMA         C. Buenavista               5               4
# 6   MOQUEGUA       SAMA              Tomasiri              12              11
# 7   MOQUEGUA       SAMA             Las Jaras              12              10
# 8   MOQUEGUA       SAMA              Cuilorca               2               1
# 9   MOQUEGUA       SAMA                 TOTAL               0               0
# 10  MOQUEGUA    LOCUMBA            P. Locumba              11               7
# 11  MOQUEGUA    LOCUMBA              C. Sinti               4               1
# 12  MOQUEGUA    LOCUMBA                 Chipe               5               4
# 13  MOQUEGUA    LOCUMBA               Sagollo               4               1
# 14  MOQUEGUA    LOCUMBA                 TOTAL               0               0
# 15  MOQUEGUA    ILABAYA            P. Ilabaya               8               8
# 16  MOQUEGUA    ILABAYA          C. Boroqueña               0               2
# 17  MOQUEGUA    ILABAYA                Mirave               0               1
# 18  MOQUEGUA    ILABAYA              Chululmi              13               7
# 19  MOQUEGUA    ILABAYA               Cambaya               1               0
# 20  MOQUEGUA    ILABAYA            Carumblaya               2               0
# 21  MOQUEGUA    ILABAYA                 TOTAL               0               0
# 22  MOQUEGUA  CANDARAVE          C. Candarave              25              19
# 23  MOQUEGUA  CANDARAVE               Cairani              21              10
# 24  MOQUEGUA  CANDARAVE         C, Quilahuani              22              17
# 25  MOQUEGUA  CANDARAVE               Pallata              12               6
# 26  MOQUEGUA  CANDARAVE                 TOTAL               0               0
# 27  MOQUEGUA   CURIBAYA           P. Curibaya               7               2
# 28  MOQUEGUA   CURIBAYA           A. Huanuara               8               6
# 29  MOQUEGUA   CURIBAYA                 TOTAL               0               0
# 30  MOQUEGUA     TICACO             P. Ticaco              13              23
# 31  MOQUEGUA     TICACO           A. Susapaya               3               6
# 32  MOQUEGUA     TICACO           Challahuaya               3               7
# 33  MOQUEGUA     TICACO               C. Cano               2               3
# 34  MOQUEGUA     TICACO            A. Yabroco               5               5
# 35  MOQUEGUA     TICACO  Londaniza y Coropuro               3               3
# 36  MOQUEGUA     TICACO  C. Tala y Chipispaya               3               1
# 37  MOQUEGUA     TICACO                 TOTAL               0               0
#
#    4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN  De 6 a 14 años               NaN              NaN
# 2               T.               V.               M.               T.
# 3               11               23               14               37
# 4               22               56               52              108
# 5                9               20               15               35
# 6               23               38               20               58
# 7               22               43               24               67
# 8                3                5               13               18
# 9                0                0                0                0
# 10              18               80               63              143
# 11               5               32               18               50
# 12               9               15               12               27
# 13               5               10               10               20
# 14               0                0                0                0
# 15              16               69               51              120
# 16               2                7                8               15
# 17               1               14                5               19
# 18              20               26               24               50
# 19               1               20               12               32
# 20               2               14                8               22
# 21               0                0                0                0
# 22              44               99               69              168
# 23              31               42               32               74
# 24              39               28               32               60
# 25              18               20               19               39
# 26               0                0                0                0
# 27               9               37               17               54
# 28              14               29               17               46
# 29               0                0                0                0
# 30              36               37               55               92
# 31               9               17               11               28
# 32              10               10               14               24
# 33               5               11                5               16
# 34              10               18                7               25
# 35               6                6                4               10
# 36               4                7                7               14
# 37               0                0                0                0
#
#    man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0       NaN  ...                      NaN                      NaN
# 1       NaN  ...                      NaN                      NaN
# 2        v.  ...                       M.                       T.
# 3         6  ...                       18                       48
# 4        23  ...                       70                      136
# 5         6  ...                       19                       44
# 6        13  ...                       31                       81
# 7        18  ...                       34                       88
# 8         1  ...                       14                       21
# 9         0  ...                        0                        0
# 10       41  ...                       70                      157
# 11       12  ...                       19                       55
# 12        2  ...                       16                       36
# 13        2  ...                       11                       25
# 14        0  ...                        0                        0
# 15       26  ...                       59                      136
# 16        0  ...                       10                       17
# 17        0  ...                        6                       20
# 18        4  ...                       31                       70
# 19        1  ...                       12                       33
# 20       10  ...                        8                       24
# 21        0  ...                        0                        0
# 22       41  ...                       84                      201
# 23        2  ...                       42                      105
# 24       15  ...                       49                       99
# 25        3  ...                       25                       57
# 26        0  ...                        0                        0
# 27        4  ...                       19                       62
# 28        0  ...                       23                       60
# 29        0  ...                        0                        0
# 30       28  ...                       78                      128
# 31        0  ...                       17                       37
# 32        4  ...                       21                       34
# 33        0  ...                        8                       21
# 34        0  ...                       12                       35
# 35        6  ...                        7                       16
# 36        0  ...                        8                       18
# 37        0  ...                        0                        0
#
#    peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0           NaN            NaN          NaN           NaN     NaN       NaN
# 1     Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2            V.            M.            V.            M.  Blanca  Indígena
# 3            30             18            0             0      11        28
# 4            67             70            0             0     107        15
# 5            25             19            0             0      12        17
# 6            50             31            0             0      33        27
# 7            55             34            0             0       8        14
# 8             7             14            0             0       6         3
# 9             0              0            0             0       0         0
# 10           91             70            0             0      74        43
# 11           36             19            0             0      12        21
# 12           20             16            0             0      18        14
# 13           14             11            0             0       9        13
# 14            0              0            0             0       0         0
# 15           77             59            0             0      22       114
# 16            7             10            0             0       0        17
# 17           14              6            0             0       0        20
# 18           39             31            0             0       0        70
# 19           21             12            0             0       0        33
# 20           16              8            0             0       0        24
# 21            0              0            0             0       0         0
# 22          123             88            1             0      98        77
# 23           63             41            0             1       1        63
# 24           50             49            0             0      11        84
# 25           32             25            0             0       7        40
# 26            0              0            0             0       0         0
# 27           42             19            2             0       0         9
# 28           37             23            0             0       2        58
# 29            0              0            0             0       0         0
# 30           47             77            3             1      17       111
# 31           20             17            0             0       0        37
# 32           13             21            0             0       0        34
# 33           13              8            0             0       0        21
# 34           23             12            0             0       0        35
# 35            9              7            0             0       0        16
# 36           10              8            0             0       0        18
# 37            0              0            0             0       0         0
#
#    mestizos blacks
# 0       NaN    NaN
# 1       NaN    NaN
# 2   Mestiza  Negra
# 3         4      5
# 4        11      4
# 5         0     15
# 6        14      7
# 7        27     40
# 8         4      8
# 9         0      0
# 10        3     41
# 11        1     21
# 12        0      4
# 13        0      3
# 14        0      0
# 15        0      0
# 16        0      0
# 17        0      0
# 18        0      0
# 19        0      0
# 20        0      0
# 21        0      0
# 22       37      0
# 23       41      0
# 24        4      0
# 25       10      0
# 26        0      0
# 27       54      0
# 28        0      0
# 29        0      0
# 30        0      0
# 31        0      0
# 32        0      0
# 33        0      0
# 34        0      0
# 35        0      0
# 36        0      0
# 37        0      0
#
# [38 rows x 41 columns]

# %%
tc["District"] = tc["District"].str.upper()
tc["Place"] = tc["Place"].str.upper()

# %%
tc["Place"] = tc["Place"].str.strip()

# %%
errors = tc.loc[tc["Place"]=="TOTAL"]
errors_list = errors.index.tolist()

# %%
tc_clean = tc.drop(tc.index[errors_list])
tc_clean
# Out:
#       Region   District                 Place   4_6_years_men 4_6_years_women  \
# 0   MOQUEGUA        NaN                   NaN             NaN             NaN
# 1   MOQUEGUA        NaN                   NaN  De 4 a 6 años              NaN
# 2   MOQUEGUA        NaN                   NaN              v.              M.
# 3   MOQUEGUA       SAMA         P. MORRO SAMA               7               4
# 4   MOQUEGUA       SAMA           SAMA GRANDE              11              11
# 5   MOQUEGUA       SAMA         C. BUENAVISTA               5               4
# 6   MOQUEGUA       SAMA              TOMASIRI              12              11
# 7   MOQUEGUA       SAMA             LAS JARAS              12              10
# 8   MOQUEGUA       SAMA              CUILORCA               2               1
# 10  MOQUEGUA    LOCUMBA            P. LOCUMBA              11               7
# 11  MOQUEGUA    LOCUMBA              C. SINTI               4               1
# 12  MOQUEGUA    LOCUMBA                 CHIPE               5               4
# 13  MOQUEGUA    LOCUMBA               SAGOLLO               4               1
# 15  MOQUEGUA    ILABAYA            P. ILABAYA               8               8
# 16  MOQUEGUA    ILABAYA          C. BOROQUEÑA               0               2
# 17  MOQUEGUA    ILABAYA                MIRAVE               0               1
# 18  MOQUEGUA    ILABAYA              CHULULMI              13               7
# 19  MOQUEGUA    ILABAYA               CAMBAYA               1               0
# 20  MOQUEGUA    ILABAYA            CARUMBLAYA               2               0
# 22  MOQUEGUA  CANDARAVE          C. CANDARAVE              25              19
# 23  MOQUEGUA  CANDARAVE               CAIRANI              21              10
# 24  MOQUEGUA  CANDARAVE         C, QUILAHUANI              22              17
# 25  MOQUEGUA  CANDARAVE               PALLATA              12               6
# 27  MOQUEGUA   CURIBAYA           P. CURIBAYA               7               2
# 28  MOQUEGUA   CURIBAYA           A. HUANUARA               8               6
# 30  MOQUEGUA     TICACO             P. TICACO              13              23
# 31  MOQUEGUA     TICACO           A. SUSAPAYA               3               6
# 32  MOQUEGUA     TICACO           CHALLAHUAYA               3               7
# 33  MOQUEGUA     TICACO               C. CANO               2               3
# 34  MOQUEGUA     TICACO            A. YABROCO               5               5
# 35  MOQUEGUA     TICACO  LONDANIZA Y COROPURO               3               3
# 36  MOQUEGUA     TICACO  C. TALA Y CHIPISPAYA               3               1
#
#    4_6_years_total   6_14_years_men 6_14_years_women 6_14_years_total  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN  De 6 a 14 años               NaN              NaN
# 2               T.               V.               M.               T.
# 3               11               23               14               37
# 4               22               56               52              108
# 5                9               20               15               35
# 6               23               38               20               58
# 7               22               43               24               67
# 8                3                5               13               18
# 10              18               80               63              143
# 11               5               32               18               50
# 12               9               15               12               27
# 13               5               10               10               20
# 15              16               69               51              120
# 16               2                7                8               15
# 17               1               14                5               19
# 18              20               26               24               50
# 19               1               20               12               32
# 20               2               14                8               22
# 22              44               99               69              168
# 23              31               42               32               74
# 24              39               28               32               60
# 25              18               20               19               39
# 27               9               37               17               54
# 28              14               29               17               46
# 30              36               37               55               92
# 31               9               17               11               28
# 32              10               10               14               24
# 33               5               11                5               16
# 34              10               18                7               25
# 35               6                6                4               10
# 36               4                7                7               14
#
#    man_read  ... not_finished_instr_women not_finished_instr_total  \
# 0       NaN  ...                      NaN                      NaN
# 1       NaN  ...                      NaN                      NaN
# 2        v.  ...                       M.                       T.
# 3         6  ...                       18                       48
# 4        23  ...                       70                      136
# 5         6  ...                       19                       44
# 6        13  ...                       31                       81
# 7        18  ...                       34                       88
# 8         1  ...                       14                       21
# 10       41  ...                       70                      157
# 11       12  ...                       19                       55
# 12        2  ...                       16                       36
# 13        2  ...                       11                       25
# 15       26  ...                       59                      136
# 16        0  ...                       10                       17
# 17        0  ...                        6                       20
# 18        4  ...                       31                       70
# 19        1  ...                       12                       33
# 20       10  ...                        8                       24
# 22       41  ...                       84                      201
# 23        2  ...                       42                      105
# 24       15  ...                       49                       99
# 25        3  ...                       25                       57
# 27        4  ...                       19                       62
# 28        0  ...                       23                       60
# 30       28  ...                       78                      128
# 31        0  ...                       17                       37
# 32        4  ...                       21                       34
# 33        0  ...                        8                       21
# 34        0  ...                       12                       35
# 35        6  ...                        7                       16
# 36        0  ...                        8                       18
#
#    peruvian_men peruvian_women  foreign_men foreign_women  whites   natives  \
# 0           NaN            NaN          NaN           NaN     NaN       NaN
# 1     Peruanos             NaN  Extranjeros           NaN     NaN       NaN
# 2            V.            M.            V.            M.  Blanca  Indígena
# 3            30             18            0             0      11        28
# 4            67             70            0             0     107        15
# 5            25             19            0             0      12        17
# 6            50             31            0             0      33        27
# 7            55             34            0             0       8        14
# 8             7             14            0             0       6         3
# 10           91             70            0             0      74        43
# 11           36             19            0             0      12        21
# 12           20             16            0             0      18        14
# 13           14             11            0             0       9        13
# 15           77             59            0             0      22       114
# 16            7             10            0             0       0        17
# 17           14              6            0             0       0        20
# 18           39             31            0             0       0        70
# 19           21             12            0             0       0        33
# 20           16              8            0             0       0        24
# 22          123             88            1             0      98        77
# 23           63             41            0             1       1        63
# 24           50             49            0             0      11        84
# 25           32             25            0             0       7        40
# 27           42             19            2             0       0         9
# 28           37             23            0             0       2        58
# 30           47             77            3             1      17       111
# 31           20             17            0             0       0        37
# 32           13             21            0             0       0        34
# 33           13              8            0             0       0        21
# 34           23             12            0             0       0        35
# 35            9              7            0             0       0        16
# 36           10              8            0             0       0        18
#
#    mestizos blacks
# 0       NaN    NaN
# 1       NaN    NaN
# 2   Mestiza  Negra
# 3         4      5
# 4        11      4
# 5         0     15
# 6        14      7
# 7        27     40
# 8         4      8
# 10        3     41
# 11        1     21
# 12        0      4
# 13        0      3
# 15        0      0
# 16        0      0
# 17        0      0
# 18        0      0
# 19        0      0
# 20        0      0
# 22       37      0
# 23       41      0
# 24        4      0
# 25       10      0
# 27       54      0
# 28        0      0
# 30        0      0
# 31        0      0
# 32        0      0
# 33        0      0
# 34        0      0
# 35        0      0
# 36        0      0
#
# [32 rows x 41 columns]

# %%
tc_clean = tc_clean.drop([0, 1, 2],axis=0)
tc_clean
# Out:
#       Region   District                 Place 4_6_years_men 4_6_years_women  \
# 3   MOQUEGUA       SAMA         P. MORRO SAMA             7               4
# 4   MOQUEGUA       SAMA           SAMA GRANDE            11              11
# 5   MOQUEGUA       SAMA         C. BUENAVISTA             5               4
# 6   MOQUEGUA       SAMA              TOMASIRI            12              11
# 7   MOQUEGUA       SAMA             LAS JARAS            12              10
# 8   MOQUEGUA       SAMA              CUILORCA             2               1
# 10  MOQUEGUA    LOCUMBA            P. LOCUMBA            11               7
# 11  MOQUEGUA    LOCUMBA              C. SINTI             4               1
# 12  MOQUEGUA    LOCUMBA                 CHIPE             5               4
# 13  MOQUEGUA    LOCUMBA               SAGOLLO             4               1
# 15  MOQUEGUA    ILABAYA            P. ILABAYA             8               8
# 16  MOQUEGUA    ILABAYA          C. BOROQUEÑA             0               2
# 17  MOQUEGUA    ILABAYA                MIRAVE             0               1
# 18  MOQUEGUA    ILABAYA              CHULULMI            13               7
# 19  MOQUEGUA    ILABAYA               CAMBAYA             1               0
# 20  MOQUEGUA    ILABAYA            CARUMBLAYA             2               0
# 22  MOQUEGUA  CANDARAVE          C. CANDARAVE            25              19
# 23  MOQUEGUA  CANDARAVE               CAIRANI            21              10
# 24  MOQUEGUA  CANDARAVE         C, QUILAHUANI            22              17
# 25  MOQUEGUA  CANDARAVE               PALLATA            12               6
# 27  MOQUEGUA   CURIBAYA           P. CURIBAYA             7               2
# 28  MOQUEGUA   CURIBAYA           A. HUANUARA             8               6
# 30  MOQUEGUA     TICACO             P. TICACO            13              23
# 31  MOQUEGUA     TICACO           A. SUSAPAYA             3               6
# 32  MOQUEGUA     TICACO           CHALLAHUAYA             3               7
# 33  MOQUEGUA     TICACO               C. CANO             2               3
# 34  MOQUEGUA     TICACO            A. YABROCO             5               5
# 35  MOQUEGUA     TICACO  LONDANIZA Y COROPURO             3               3
# 36  MOQUEGUA     TICACO  C. TALA Y CHIPISPAYA             3               1
#
#    4_6_years_total 6_14_years_men 6_14_years_women 6_14_years_total man_read  \
# 3               11             23               14               37        6
# 4               22             56               52              108       23
# 5                9             20               15               35        6
# 6               23             38               20               58       13
# 7               22             43               24               67       18
# 8                3              5               13               18        1
# 10              18             80               63              143       41
# 11               5             32               18               50       12
# 12               9             15               12               27        2
# 13               5             10               10               20        2
# 15              16             69               51              120       26
# 16               2              7                8               15        0
# 17               1             14                5               19        0
# 18              20             26               24               50        4
# 19               1             20               12               32        1
# 20               2             14                8               22       10
# 22              44             99               69              168       41
# 23              31             42               32               74        2
# 24              39             28               32               60       15
# 25              18             20               19               39        3
# 27               9             37               17               54        4
# 28              14             29               17               46        0
# 30              36             37               55               92       28
# 31               9             17               11               28        0
# 32              10             10               14               24        4
# 33               5             11                5               16        0
# 34              10             18                7               25        0
# 35               6              6                4               10        6
# 36               4              7                7               14        0
#
#     ... not_finished_instr_women not_finished_instr_total peruvian_men  \
# 3   ...                       18                       48           30
# 4   ...                       70                      136           67
# 5   ...                       19                       44           25
# 6   ...                       31                       81           50
# 7   ...                       34                       88           55
# 8   ...                       14                       21            7
# 10  ...                       70                      157           91
# 11  ...                       19                       55           36
# 12  ...                       16                       36           20
# 13  ...                       11                       25           14
# 15  ...                       59                      136           77
# 16  ...                       10                       17            7
# 17  ...                        6                       20           14
# 18  ...                       31                       70           39
# 19  ...                       12                       33           21
# 20  ...                        8                       24           16
# 22  ...                       84                      201          123
# 23  ...                       42                      105           63
# 24  ...                       49                       99           50
# 25  ...                       25                       57           32
# 27  ...                       19                       62           42
# 28  ...                       23                       60           37
# 30  ...                       78                      128           47
# 31  ...                       17                       37           20
# 32  ...                       21                       34           13
# 33  ...                        8                       21           13
# 34  ...                       12                       35           23
# 35  ...                        7                       16            9
# 36  ...                        8                       18           10
#
#    peruvian_women foreign_men foreign_women whites natives mestizos blacks
# 3              18           0             0     11      28        4      5
# 4              70           0             0    107      15       11      4
# 5              19           0             0     12      17        0     15
# 6              31           0             0     33      27       14      7
# 7              34           0             0      8      14       27     40
# 8              14           0             0      6       3        4      8
# 10             70           0             0     74      43        3     41
# 11             19           0             0     12      21        1     21
# 12             16           0             0     18      14        0      4
# 13             11           0             0      9      13        0      3
# 15             59           0             0     22     114        0      0
# 16             10           0             0      0      17        0      0
# 17              6           0             0      0      20        0      0
# 18             31           0             0      0      70        0      0
# 19             12           0             0      0      33        0      0
# 20              8           0             0      0      24        0      0
# 22             88           1             0     98      77       37      0
# 23             41           0             1      1      63       41      0
# 24             49           0             0     11      84        4      0
# 25             25           0             0      7      40       10      0
# 27             19           2             0      0       9       54      0
# 28             23           0             0      2      58        0      0
# 30             77           3             1     17     111        0      0
# 31             17           0             0      0      37        0      0
# 32             21           0             0      0      34        0      0
# 33              8           0             0      0      21        0      0
# 34             12           0             0      0      35        0      0
# 35              7           0             0      0      16        0      0
# 36              8           0             0      0      18        0      0
#
# [29 rows x 41 columns]

# %%
tc_clean = tc_clean.reset_index()
tc_clean
# Out:
#     index    Region   District                 Place 4_6_years_men  \
# 0       3  MOQUEGUA       SAMA         P. MORRO SAMA             7
# 1       4  MOQUEGUA       SAMA           SAMA GRANDE            11
# 2       5  MOQUEGUA       SAMA         C. BUENAVISTA             5
# 3       6  MOQUEGUA       SAMA              TOMASIRI            12
# 4       7  MOQUEGUA       SAMA             LAS JARAS            12
# 5       8  MOQUEGUA       SAMA              CUILORCA             2
# 6      10  MOQUEGUA    LOCUMBA            P. LOCUMBA            11
# 7      11  MOQUEGUA    LOCUMBA              C. SINTI             4
# 8      12  MOQUEGUA    LOCUMBA                 CHIPE             5
# 9      13  MOQUEGUA    LOCUMBA               SAGOLLO             4
# 10     15  MOQUEGUA    ILABAYA            P. ILABAYA             8
# 11     16  MOQUEGUA    ILABAYA          C. BOROQUEÑA             0
# 12     17  MOQUEGUA    ILABAYA                MIRAVE             0
# 13     18  MOQUEGUA    ILABAYA              CHULULMI            13
# 14     19  MOQUEGUA    ILABAYA               CAMBAYA             1
# 15     20  MOQUEGUA    ILABAYA            CARUMBLAYA             2
# 16     22  MOQUEGUA  CANDARAVE          C. CANDARAVE            25
# 17     23  MOQUEGUA  CANDARAVE               CAIRANI            21
# 18     24  MOQUEGUA  CANDARAVE         C, QUILAHUANI            22
# 19     25  MOQUEGUA  CANDARAVE               PALLATA            12
# 20     27  MOQUEGUA   CURIBAYA           P. CURIBAYA             7
# 21     28  MOQUEGUA   CURIBAYA           A. HUANUARA             8
# 22     30  MOQUEGUA     TICACO             P. TICACO            13
# 23     31  MOQUEGUA     TICACO           A. SUSAPAYA             3
# 24     32  MOQUEGUA     TICACO           CHALLAHUAYA             3
# 25     33  MOQUEGUA     TICACO               C. CANO             2
# 26     34  MOQUEGUA     TICACO            A. YABROCO             5
# 27     35  MOQUEGUA     TICACO  LONDANIZA Y COROPURO             3
# 28     36  MOQUEGUA     TICACO  C. TALA Y CHIPISPAYA             3
#
#    4_6_years_women 4_6_years_total 6_14_years_men 6_14_years_women  \
# 0                4              11             23               14
# 1               11              22             56               52
# 2                4               9             20               15
# 3               11              23             38               20
# 4               10              22             43               24
# 5                1               3              5               13
# 6                7              18             80               63
# 7                1               5             32               18
# 8                4               9             15               12
# 9                1               5             10               10
# 10               8              16             69               51
# 11               2               2              7                8
# 12               1               1             14                5
# 13               7              20             26               24
# 14               0               1             20               12
# 15               0               2             14                8
# 16              19              44             99               69
# 17              10              31             42               32
# 18              17              39             28               32
# 19               6              18             20               19
# 20               2               9             37               17
# 21               6              14             29               17
# 22              23              36             37               55
# 23               6               9             17               11
# 24               7              10             10               14
# 25               3               5             11                5
# 26               5              10             18                7
# 27               3               6              6                4
# 28               1               4              7                7
#
#    6_14_years_total  ... not_finished_instr_women not_finished_instr_total  \
# 0                37  ...                       18                       48
# 1               108  ...                       70                      136
# 2                35  ...                       19                       44
# 3                58  ...                       31                       81
# 4                67  ...                       34                       88
# 5                18  ...                       14                       21
# 6               143  ...                       70                      157
# 7                50  ...                       19                       55
# 8                27  ...                       16                       36
# 9                20  ...                       11                       25
# 10              120  ...                       59                      136
# 11               15  ...                       10                       17
# 12               19  ...                        6                       20
# 13               50  ...                       31                       70
# 14               32  ...                       12                       33
# 15               22  ...                        8                       24
# 16              168  ...                       84                      201
# 17               74  ...                       42                      105
# 18               60  ...                       49                       99
# 19               39  ...                       25                       57
# 20               54  ...                       19                       62
# 21               46  ...                       23                       60
# 22               92  ...                       78                      128
# 23               28  ...                       17                       37
# 24               24  ...                       21                       34
# 25               16  ...                        8                       21
# 26               25  ...                       12                       35
# 27               10  ...                        7                       16
# 28               14  ...                        8                       18
#
#    peruvian_men peruvian_women foreign_men foreign_women whites natives  \
# 0            30             18           0             0     11      28
# 1            67             70           0             0    107      15
# 2            25             19           0             0     12      17
# 3            50             31           0             0     33      27
# 4            55             34           0             0      8      14
# 5             7             14           0             0      6       3
# 6            91             70           0             0     74      43
# 7            36             19           0             0     12      21
# 8            20             16           0             0     18      14
# 9            14             11           0             0      9      13
# 10           77             59           0             0     22     114
# 11            7             10           0             0      0      17
# 12           14              6           0             0      0      20
# 13           39             31           0             0      0      70
# 14           21             12           0             0      0      33
# 15           16              8           0             0      0      24
# 16          123             88           1             0     98      77
# 17           63             41           0             1      1      63
# 18           50             49           0             0     11      84
# 19           32             25           0             0      7      40
# 20           42             19           2             0      0       9
# 21           37             23           0             0      2      58
# 22           47             77           3             1     17     111
# 23           20             17           0             0      0      37
# 24           13             21           0             0      0      34
# 25           13              8           0             0      0      21
# 26           23             12           0             0      0      35
# 27            9              7           0             0      0      16
# 28           10              8           0             0      0      18
#
#    mestizos blacks
# 0         4      5
# 1        11      4
# 2         0     15
# 3        14      7
# 4        27     40
# 5         4      8
# 6         3     41
# 7         1     21
# 8         0      4
# 9         0      3
# 10        0      0
# 11        0      0
# 12        0      0
# 13        0      0
# 14        0      0
# 15        0      0
# 16       37      0
# 17       41      0
# 18        4      0
# 19       10      0
# 20       54      0
# 21        0      0
# 22        0      0
# 23        0      0
# 24        0      0
# 25        0      0
# 26        0      0
# 27        0      0
# 28        0      0
#
# [29 rows x 42 columns]

# %%
a = tc_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# finished_instr_men          object
# finished_instr_women        object
# finished_instr_total        object
# not_finished_instr_men      object
# not_finished_instr_women    object
# not_finished_instr_total    object
# peruvian_men                object
# peruvian_women              object
# foreign_men                 object
# foreign_women               object
# whites                      object
# natives                     object
# mestizos                    object
# blacks                      object
# dtype: object

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# finished_instr_men           int64
# finished_instr_women         int64
# finished_instr_total         int64
# not_finished_instr_men       int64
# not_finished_instr_women     int64
# not_finished_instr_total     int64
# peruvian_men                 int64
# peruvian_women               int64
# foreign_men                  int64
# foreign_women                int64
# whites                       int64
# natives                      int64
# mestizos                     int64
# blacks                       int64
# dtype: object

# %%
Code1= a12.to_excel("Region_Tacna.xlsx")
Code1
