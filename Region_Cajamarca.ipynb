# %%
import pandas as pd
import numpy as np

# %%
# Llamamos a la primera hoja 
## importar el csv descargado en nuestra computadora

CAJAMARCA_1 = pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/CAJAMARCA_FINALIZADO.xlsx")

# %%
# agregamos que en Region sea por defecto CAJAMARCA
CAJAMARCA_1["Region"] = "CAJAMARCA"

# %%
Region = CAJAMARCA_1["Region"]
CAJAMARCA_1.drop(labels = "Region", axis=1, inplace = True)
CAJAMARCA_1.insert(0, "Region", Region)

# %%
# Reemplazamos las variables de la data sucia por las que vamos a usar 
CAJAMARCA_1.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
CAJAMARCA_1["District"] = CAJAMARCA_1["District"].str.upper()
CAJAMARCA_1["Place"] = CAJAMARCA_1["Place"].str.upper()

# %%
CAJAMARCA_1["Place"] = CAJAMARCA_1["Place"].str.strip()
# Find errors with string = Total
errors =CAJAMARCA_1.loc[CAJAMARCA_1["Place"]=="TOTAL"]
error_list = errors.index.tolist()

cajamarca_clean = CAJAMARCA_1.drop(CAJAMARCA_1.index[error_list])
cajamarca_clean
# Out:
#        Region    District             Place   4_6_years_men 4_6_years_women  \
# 0   CAJAMARCA         NaN               NaN             NaN             NaN
# 1   CAJAMARCA         NaN               NaN  De 4 a 6 años              NaN
# 2   CAJAMARCA         NaN               NaN              v.              M.
# 3   CAJAMARCA   CAJAMARCA         CAJAMARCA             200             204
# 4   CAJAMARCA   CAJAMARCA    C.HUANBACANCHA              42              55
# 5   CAJAMARCA   CAJAMARCA            OTUZCO              84              92
# 6   CAJAMARCA   CAJAMARCA      H.PARIAMARCA              23              20
# 7   CAJAMARCA   CAJAMARCA  C.BAÑOS DEL INCA              22              16
# 9   CAJAMARCA      COSPÁN            COSPÁN              74              68
# 10  CAJAMARCA      COSPÁN      P. SAN JORGE              24              25
# 12  CAJAMARCA     MATARPA            MATARÁ              23              23
# ...

# %%
cajamarca_clean = cajamarca_clean.drop([0, 1, 2],axis=0)
cajamarca_clean
# Out:
#        Region    District             Place 4_6_years_men 4_6_years_women  \
# 3   CAJAMARCA   CAJAMARCA         CAJAMARCA           200             204
# 4   CAJAMARCA   CAJAMARCA    C.HUANBACANCHA            42              55
# 5   CAJAMARCA   CAJAMARCA            OTUZCO            84              92
# 6   CAJAMARCA   CAJAMARCA      H.PARIAMARCA            23              20
# 7   CAJAMARCA   CAJAMARCA  C.BAÑOS DEL INCA            22              16
# 9   CAJAMARCA      COSPÁN            COSPÁN            74              68
# 10  CAJAMARCA      COSPÁN      P. SAN JORGE            24              25
# 12  CAJAMARCA     MATARPA            MATARÁ            23              23
# 14  CAJAMARCA    CHETILLA          CHETILLA             9               3
# 15  CAJAMARCA    CHETILLA       P. CUMBICUS             9               3
# 17  CAJAMARCA    YACANORA          YACANORA            44              45
# 19  CAJAMARCA   MAGDALENA         MADGALENA            17              10
# ...

# %%
cajamarca_clean = cajamarca_clean.reset_index()
cajamarca_clean
# Out:
#     index     Region    District             Place 4_6_years_men  \
# 0       3  CAJAMARCA   CAJAMARCA         CAJAMARCA           200
# 1       4  CAJAMARCA   CAJAMARCA    C.HUANBACANCHA            42
# 2       5  CAJAMARCA   CAJAMARCA            OTUZCO            84
# 3       6  CAJAMARCA   CAJAMARCA      H.PARIAMARCA            23
# 4       7  CAJAMARCA   CAJAMARCA  C.BAÑOS DEL INCA            22
# 5       9  CAJAMARCA      COSPÁN            COSPÁN            74
# 6      10  CAJAMARCA      COSPÁN      P. SAN JORGE            24
# 7      12  CAJAMARCA     MATARPA            MATARÁ            23
# 8      14  CAJAMARCA    CHETILLA          CHETILLA             9
# 9      15  CAJAMARCA    CHETILLA       P. CUMBICUS             9
# 10     17  CAJAMARCA    YACANORA          YACANORA            44
# 11     19  CAJAMARCA   MAGDALENA         MADGALENA            17
# 12     21  CAJAMARCA    ENCAÑADA          ENCAÑADA            50
# ...

# %%
a = cajamarca_clean.drop("index", axis=1)
a.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men               object
# 4_6_years_women             object
# 4_6_years_total             object
# 6_14_years_men              object
# 6_14_years_women            object
# 6_14_years_total            object
# man_read                    object
# women_read                  object
# total_read                  object
# men_not_read                object
# women_not_read              object
# total_not_read              object
# man_write                   object
# women_write                 object
# total_write                 object
# men_not_write               object
# women_not_write             object
# total_not_write             object
# instruction_men             object
# instruction_women           object
# instruction_total           object
# no_instruction_men          object
# no_instruction_women        object
# no_instruction_total        object
# ...

# %%
errors1 =a.loc[a["Place"]=="TOTAL"]
errors1
# Out:
# Empty DataFrame
# Columns: [Region, District, Place, 4_6_years_men, 4_6_years_women, 4_6_years_total, 6_14_years_men, 6_14_years_women, 6_14_years_total, man_read, women_read, total_read, men_not_read, women_not_read, total_not_read, man_write, women_write, total_write, men_not_write, women_not_write, total_not_write, instruction_men, instruction_women, instruction_total, no_instruction_men, no_instruction_women, no_instruction_total, finished_instr_men, finished_instr_women, finished_instr_total, not_finished_instr_men, not_finished_instr_women, not_finished_instr_total, peruvian_men, peruvian_women, foreign_men, foreign_women, whites, natives, mestizos, blacks]
# Index: []
#
# [0 rows x 41 columns]

# %%
a1=a.dtypes

# %%
a12= a.infer_objects()
a12.dtypes
# Out:
# Region                      object
# District                    object
# Place                       object
# 4_6_years_men                int64
# 4_6_years_women              int64
# 4_6_years_total              int64
# 6_14_years_men               int64
# 6_14_years_women             int64
# 6_14_years_total             int64
# man_read                     int64
# women_read                   int64
# total_read                   int64
# men_not_read                 int64
# women_not_read               int64
# total_not_read               int64
# man_write                    int64
# women_write                  int64
# total_write                  int64
# men_not_write                int64
# women_not_write              int64
# total_not_write              int64
# instruction_men              int64
# instruction_women            int64
# instruction_total            int64
# no_instruction_men           int64
# no_instruction_women         int64
# no_instruction_total         int64
# ...

# %%
Code1= a12.to_excel("Region_Cajamarca.xlsx")
Code1

# %%
a12
# Out:
#        Region    District             Place  4_6_years_men  4_6_years_women  \
# 0   CAJAMARCA   CAJAMARCA         CAJAMARCA            200              204
# 1   CAJAMARCA   CAJAMARCA    C.HUANBACANCHA             42               55
# 2   CAJAMARCA   CAJAMARCA            OTUZCO             84               92
# 3   CAJAMARCA   CAJAMARCA      H.PARIAMARCA             23               20
# 4   CAJAMARCA   CAJAMARCA  C.BAÑOS DEL INCA             22               16
# 5   CAJAMARCA      COSPÁN            COSPÁN             74               68
# 6   CAJAMARCA      COSPÁN      P. SAN JORGE             24               25
# 7   CAJAMARCA     MATARPA            MATARÁ             23               23
# 8   CAJAMARCA    CHETILLA          CHETILLA              9                3
# 9   CAJAMARCA    CHETILLA       P. CUMBICUS              9                3
# 10  CAJAMARCA    YACANORA          YACANORA             44               45
# ...

# %%
# Con este código encontraremso las filas que tenan "Total" dentro de la columna "PLACE"
cj= CAJAMARCA_1.loc[CAJAMARCA_1["Place"]=="Total"]

# %%
# Procedemos a borrar esos datos que no nos sirven
Cj= CAJAMARCA_1.drop(CAJAMARCA_1.index[[8,11,13,16,18,20,22,24,40,50,62,64]])
Cj1 = Cj.drop([0, 1, 2],axis=0)

# %% [markdown]
# **HOJA 2**

# %%
a =pd.read_excel(r"C:\Users\egonz\Desktop\LIMPIAR DATA/CAJAMARCA_FINALIZADO.xlsx","73-74")

# %%
a["Region"] = "CAJAMARCA"

# %%
Region = a["Region"]
a.drop(labels = "Region", axis=1, inplace = True)
a.insert(0, "Region", Region)

# %%
a.columns= ["Region","District","Place","4_6_years_men","4_6_years_women"
,"4_6_years_total","6_14_years_men","6_14_years_women","6_14_years_total","man_read","women_read","total_read","men_not_read","women_not_read","total_not_read","man_write","women_write","total_write","men_not_write","women_not_write","total_not_write","instruction_men","instruction_women","instruction_total","no_instruction_men","no_instruction_women","no_instruction_total","finished_instr_men","finished_instr_women","finished_instr_total","not_finished_instr_men","not_finished_instr_women","not_finished_instr_total","peruvian_men"
 , "peruvian_women", "foreign_men", "foreign_women", "whites", "natives", "mestizos" , "blacks"]

# %%
Cj2=a.loc[a["Place"]=="Total"]
Cj2

# %%
aea= a.drop(a.index[[13,28,30]])
qwe = aea.drop([0, 1, 2],axis=0)

# %%
FUSION1_2 = pd.concat([Cj1,qwe])
FUSION1_2

# %%
 Code= FUSION1_2.to_excel("cajamarca_finalizado.xlsx")
